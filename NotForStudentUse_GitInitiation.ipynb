# %%
import os
from google.colab import drive
from pathlib import Path

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
PATH = Path('/content/drive/MyDrive/Data_Shortcut/Notebooks')

# %%
os.chdir(PATH)

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1HO3yoD8HWsntn5dWbaSB55ZchXdofIbn/Notebooks

# %%
# !ls
# Out:
# GitInitiation.ipynb
# Module0_Intro_to_medical_imaging_formats.ipynb
# Module1_NB0_ADNI_UnzipAndRemoveDuplicates.ipynb
# Module1_NB1_ADNI_PET_DataWrangling.ipynb
# Module1_NB2_ADNI_MRI_DataWrangling.ipynb
# Module1_NB3_ADNI_ADClassification.ipynb
# Module2_NB1_BraTS_DataProcessing.ipynb
# Module2_NB2_BraTS_TumorSegmentation.ipynb

# %%
# !git init

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	deleted:    .gitignore
# 	deleted:    GitInitiation.ipynb
# 	renamed:    Module0_Intro_to_medical_imaging_formats.ipynb -> Module0_NB1_Intro_Medical_Imaging_Formats.ipynb
# 	new file:   Module0_NB2_v0.ipynb
# 	modified:   Module1_NB3_ADNI_ADClassification.ipynb
# 	new file:   NotForStudentUse_GitInitiation.ipynb
# 	renamed:    Module1_NB0_ADNI_UnzipAndRemoveDuplicates.ipynb -> NotForStudentUse_Module1_NB0_ADNI_UnzipAndRemoveDuplicates.ipynb

# %%
# !git config --global user.email "julia.cluceru@gmail.com"

# %%
# !git config --global user.name "julclu"

# %%
# !git commit -m "Adding in the Module 0 classfiier"
# Out:
# [main 405a9f8] Adding in the Module 0 classfiier
#  7 files changed, 3 insertions(+), 3 deletions(-)
#  delete mode 100644 .gitignore
#  delete mode 100644 GitInitiation.ipynb
#  rename Module0_Intro_to_medical_imaging_formats.ipynb => Module0_NB1_Intro_Medical_Imaging_Formats.ipynb (100%)
#  create mode 100644 Module0_NB2_v0.ipynb
#  rewrite Module1_NB3_ADNI_ADClassification.ipynb (79%)
#  create mode 100644 NotForStudentUse_GitInitiation.ipynb
#  rename Module1_NB0_ADNI_UnzipAndRemoveDuplicates.ipynb => NotForStudentUse_Module1_NB0_ADNI_UnzipAndRemoveDuplicates.ipynb (100%)

# %%
# !git remote remove origin
# !git remote add origin https://julclu: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@github.com/julclu/CSC509.git

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 1.13 MiB | 3.82 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/julclu/CSC509.git
#    d81dafb..405a9f8  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
