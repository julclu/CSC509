# %% [markdown]
# # Module 1, Notebook 1 - Wrangling ADNI Imaging and Outcome Data

# %% [markdown]
# ## Instructions
#
# Please make a copy and rename it with your name (ex: Module1_NB1_Ilmi_Yoon). All grading points should be explored in the notebook but some can be done in a separate pdf file.
#
# *Graded questions will be listed with "Q:" followed by the corresponding points.*
#
# You will be submitting **a pdf** file containing **the url of your own Module1_NB1.**
#
#
# ---

# %% [markdown]
# # Introduction
#
# ## 1. Mounting and Accessing the Data

# %%
import numpy as np
import os
from pathlib import Path
import glob
import pandas as pd
from collections import Counter
import math
from tqdm import tqdm

# %%
from google.colab import drive

# %% [markdown]
# Because we are working on data stored in Google Drive, the following steps will need to be taken:
# 1. Mount Google drive through using drive.mount('/content/drive')
# 2. Ceate a shortcut your personal Google Drive home directory to the location where the data is through:
#   * Navigating to https://drive.google.com/
#   * Click "My Drive"
#   * Click the "+ New" button, add folder, and name it Data_Shortcut. This will be the place you can access to the data.
#   * From drive.google.com, navigate to "Shared with me", click on rev3, CS509_Data
#   * Right click on Module1_ADNI and click "Add shortcut to drive"
#   * Add to the Data_Shortcut you just created in MyDrive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = Path('/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/')

# %% [markdown]
# We want to make sure we've mounted the data properly and that there are a good number of patients in the PET data folder:

# %%
num_pts = len(os.listdir(Path(DATA_PATH,'FDGPET', 'ADNI')))
print(f'There are {num_pts} patients in the folder')
# Out:
# There are 523 patients in the folder

# %% [markdown]
# Here, we want to see if we can get the cognitive group or specific outcomes for the patients that are in the folder. In order to do that, we downloaded a CSV file associated with the PET data from the ADNI website. List the files in the CSV directory below and read them in, inspect the columns and rows of the CSV file:

# %%
os.listdir(Path(DATA_PATH, 'CSVS',))
# Out:
# ['ADNI_PET_MiddleSlices_UniformResolution_Averages.csv',
#  'ADNI_2_AV45_base_10_01_2021.csv',
#  'ADNI2_3_base_screen_AV45_10_08_2021.csv',
#  'adnim.csv',
#  'ADNI_Amyloid_Status_AV45_KAIST.csv',
#  'ADNI_Amyloid_Status_UPenn_UCBerkeley.csv',
#  'ADNI_PET_MiddleSlices_ClinicalData.csv']

# %%
data_df = pd.read_csv(Path(DATA_PATH,'CSVS/FDG_PET_CN_AD_12_07_2021.csv'))

# %%
data_df.shape
# Out:
# (1501, 12)

# %%
data_df.head()
# Out:
#   Image Data ID     Subject Group Sex  ...      Type    Acq Date Format  Downloaded
# 0      I1479867  941_S_6962    AD   F  ...  Original   8/10/2021    DCM  12/02/2021
# 1      I1295819  941_S_6854    AD   M  ...  Original   2/24/2020    DCM  12/02/2021
# 2       I283469  941_S_4376    CN   F  ...  Original   2/08/2012    DCM  12/02/2021
# 3       I274743  941_S_4365    CN   M  ...  Original  12/30/2011    DCM  12/02/2021
# 4       I420334  941_S_4365    CN   M  ...  Original   4/16/2014    DCM  12/02/2021
#
# [5 rows x 12 columns]

# %% [markdown]
# Below, I want to see if the patients in the PET folder are in in the CSV file that we downloaded:

# %%
pt_in_csv = []
for patient_id in os.listdir(DATA_PATH/'FDGPET'/'ADNI'): 
  if patient_id in data_df.Subject.tolist():
    pt_in_csv.append("yes")
  else: 
    pt_in_csv.append('no')
Counter(pt_in_csv)
# Out:
# Counter({'yes': 523})

# %%
print('There are ' + str(len(glob.glob(str(Path(DATA_PATH, 'FDGPET','ADNI', '*', '*')))))+ ' files in the in the patient folders')
# Out:
# There are 668 files in the in the patient folders

# %% [markdown]
# So there are multiple PET images files in each folder. Let's see what kinds of PET there are.

# %% [markdown]
# ## 2. Investigating the types of imaging data

# %%
Counter([x.split('/')[-1] for x in glob.glob(str(Path(DATA_PATH, 'FDGPET','ADNI', '*', '*')))]).most_common()
# Out:
# [('ADNI_Brain_PET__Raw_FDG', 66),
#  ('ADNI_Brain_PET__Raw', 39),
#  ('ADNI_Static_Brain__6x5_', 22),
#  ('30_min_3D_FDG_4i_16s', 18),
#  ('30_MIN_3D_FDG_4i_16s', 13),
#  ('ADNI_3D_Brain_ITERATIVE__FDG', 13),
#  ('30MIN_3D_FDG_4i_16s', 12),
#  ('ADNI_ITERATIVE_FDG', 11),
#  ('ADNI2_FDG__AC_', 11),
#  ('30-60_min_dynamic-3D_4i_16s__FDG', 11),
#  ('ADNI_FDG_Brain_30min_dyn', 11),
#  ('ADNI__AC___FDG', 11),
#  ('ADNI_STATIC_BRAIN__6X5_', 10),
#  ('ADNI_BRAIN_3D__FDG', 9),
#  ('30_min_3D_FDG__4i_16s', 9),
#  ('PET_WB', 8),
#  ('Dyn_ADNI-GO_128x,4i20s,256mmFOV,NoFilter___FDG', 8),
#  ('30_min_3D_FDG_-_Iter_Brain_Mode', 8),
#  ('ADNI_FDG_6F_4i_16s', 8),
#  ('ADNI_AC_FDG', 8),
#  ('3D_Brain', 7),
#  ('PET_Brain_FDG', 7),
#  ('ADNI-2-FDG', 7),
#  ('fdg_4i_16s__FDG', 7),
#  ('30_min_FDG_4i_16s', 6),
#  ('ADNI_STATIC_BRAIN', 6),
#  ('30-60_min_dynamic-3D_-_Iter__FDG', 6),
#  ('60min_Dyn_FDG_4i_16s', 5),
#  ('PET_AC_3D_Brain_ADNI-GO_FDG', 5),
#  ('EMISSION-ADNI_4i_16s__FDG', 5),
#  ('TRANSAXIAL_BRAIN_3D_FDG_IR_CTAC_NF', 5),
#  ('FDG_Dyn_6x5min_2Di_336_2z_AllPass__AC_', 5),
#  ('ADNIstaticBrain_6x5_', 4),
#  ('33f__ADNI_4i_16s', 4),
#  ('Dynamic_2_FDG_4i_16s', 4),
#  ('PET_BRAIN', 4),
#  ('ADNISTATIC6X5', 4),
#  ('ADNI_PET_Brain', 4),
#  ('3D_BRAIN_FDG_FORE', 4),
#  ('ANONYMIZED_FDG', 4),
#  ('FDG__AC_', 4),
#  ('PET-AC_Volume__Corrected___FDG', 4),
#  ('ADNI-GO_3D_Iterative_Brain_FDG', 4),
#  ('ADNI_GO_PRIMARY_FDG', 4),
#  ('PET_WB_FDG', 4),
#  ('_3D_6x300s_4i_16s__FDG', 4),
#  ('30min_3D_FDG_6i_16s', 4),
#  ('ADNIGO_-_FDG_BRAIN_STUDY', 4),
#  ('PET_ADNI__Brain', 4),
#  ('PET_Brain', 3),
#  ('60min_Dyn_FDG_-_Iter_Brain_Mode', 3),
#  ('3D_PET_Brain', 3),
#  ('EMISSION-ADNI_4i_16s', 3),
#  ('EMISSION_4i_16s__FDG', 3),
#  ('3D_Neuro_Dyna_4i_16s', 3),
#  ('ADNI-2_3D_Iterative_Brain__FDG', 3),
#  ('6x5minute_frames_4i_16s__FDG', 3),
#  ('ADNI-2_FDG_AC', 3),
#  ('PET1_FDG', 3),
#  ('ADNI_BRAIN', 3),
#  ('ADNI3_FDG__AC_', 3),
#  ('BRAIN_EMISSION_4i_16s__FDG', 3),
#  ('ADNI_GO_PRIMARY__FDG', 3),
#  ('3D_Emission_6i_16s', 3),
#  ('6x5minute_frames_-_Iter_Brai_FDG', 3),
#  ('BRAIN_DYN_EM_6i_16s', 2),
#  ('[DY_CTAC]_Brain', 2),
#  ('BRAIN', 2),
#  ('PET_168_Brain', 2),
#  ('30_MIN_3D_FDG_-_Iter_Brain_Mode', 2),
#  ('30_MIN_3D_FDG_6i_16s', 2),
#  ('EMISSION-ADNI_-_Iter_Brain_Mode', 2),
#  ('ADNI_BRAIN_FDG_2nd_15min', 2),
#  ('PET_AC_3D_BRAIN__FDG', 2),
#  ('6_fr_FDG_Brain', 2),
#  ('PET_Brain__FDG', 2),
#  ('Dyn_Brain_VPHD_6i16s_AC_FDG', 2),
#  ('DYNAMIC_Brain_AC_FDG', 2),
#  ('ADNI_STATIC_BRAIN__FDG', 2),
#  ('PET_Brain_COR_#_2', 2),
#  ('ADNI_STATIC_6X5', 2),
#  ('ADNI_static_brain__6x5_', 2),
#  ('PET2ADNI', 2),
#  ('ADNI-FDG__AC_', 2),
#  ('PET2_FDG', 2),
#  ('PET_Brain_DYNAMIC_6X5__FDG', 2),
#  ('3D_IR__FDG', 2),
#  ('BRAINap', 2),
#  ('TRANSAXIAL_BRAIN_3D_FDG_ADNI_CTAC', 2),
#  ('ADNI_BRAIN_FDG_1st_15min', 2),
#  ('FDG_PET_BRAIN_2', 2),
#  ('ADNI_FDG_6X5', 2),
#  ('ADNI2FDGBrain_6x5_', 2),
#  ('ADNI_3_FDG', 2),
#  ('ADNI_PET_BRAIN__AC___FDG', 2),
#  ('ADNI-FDG_BRAIN__AC_', 2),
#  ('3D_BRAIN_ADNI-2_ITERATIVE_FDG', 2),
#  ('022_S_0066.img__BRAIN-PASS2_', 1),
#  ('30min_Stat_FDG_-_Iter_Brain_Mod', 1),
#  ('Dynamic_1_FDG_Seg_-_Iter_Brain', 1),
#  ('BRAINAP', 1),
#  ('ADNI_static_Brain__6x5__TM', 1),
#  ('022_S_0130.img__BRAIN-PASS2_', 1),
#  ('3DFDG-BRAINSCAN-DYNAMICEMISSION', 1),
#  ('ADNISTATICBRAIN6X5', 1),
#  ('30_min_3D_FDG_Seg-_Iter_Brain_M', 1),
#  ('DYN_3D__6i_16s', 1),
#  ('ADNIStaciBrain6x5', 1),
#  ('ADNI_PET_Brain_P', 1),
#  ('022_S_0543.img__BRAIN-PASS2_', 1),
#  ('ADNI-GO-FDG', 1),
#  ('ELAN_FDG_6F_4i_16s', 1),
#  ('PET_Brain_fdg__FDG', 1),
#  ('019-S-4367-FDG', 1),
#  ('082-S-4428-E2__FDG', 1),
#  ('PET_ADNI_Iterative1__FDG', 1),
#  ('ADNI2FDGBrain_6x5_ITERATIVE', 1),
#  ('019-S-4252-FDG_', 1),
#  ('082-S-4090-E-LM__FDG', 1),
#  ('PET_Brain1_FDG', 1),
#  ('2-PET_ADNI_Iterative1__FDG', 1),
#  ('082-S-4339-FDG-E1', 1),
#  ('30-60_min_dynamic-3D_4i_16s_FDG', 1),
#  ('ADNI_STATIC_BRAIN__6x5_', 1),
#  ('127_S_0259_fdg', 1),
#  ('ADNI_3_FDG_BRAIN__AC_', 1),
#  ('ADNI3_FDG_6X5', 1),
#  ('PET_Brain_FDG_DYNAMIC', 1),
#  ('PET_Brain_168x168', 1),
#  ('PET_BRAIN__W_PATCH', 1),
#  ('PET_BRAIN_#3', 1),
#  ('PET_BRAIN_W_PATCH', 1),
#  ('3D_Neuro_Dyna_-_Copied_from_ACS', 1),
#  ('ADNISTUDY6X5', 1),
#  ('ADNIBRAIN6X5', 1),
#  ('adni_brain_127_S_1382', 1),
#  ('ADNI_STATIC_BRAIN__6x5__', 1),
#  ('_4i_16s', 1),
#  ('60_min_dynamic_4i_16s', 1),
#  ('20081024092208.', 1),
#  ('30_MIN_EMMI_4i_16s__FDG', 1),
#  ('127_S_0754_fdg', 1),
#  ('ADNI_static_brain_6x5', 1),
#  ('20081017141306.', 1),
#  ('3D_BRAIN_ADNI', 1),
#  ('PET_ADNI', 1),
#  ('andi2', 1),
#  ('adni2', 1),
#  ('ADNI_DYN_BRAIN__AC_', 1),
#  ('PET_BR_ADNI', 1),
#  ('PET_BRAIN_1__FDG', 1),
#  ('082-S-4208-E1__FDG', 1),
#  ('082-S-4208-E_-LM_FDG', 1),
#  ('3D_PET_BRAIN_ADNI-GO_FDG', 1),
#  ('3D_PET_BRAIN_ADNI-2_FDG_I_20_4', 1),
#  ('PET_Brain_FDG__AC_', 1),
#  ('BRAIN_ADNI_FDG', 1),
#  ('ADNI3-BRAIN_FDG', 1),
#  ('ADNI_Static_Brain__6x5__#2', 1),
#  ('3D_Brain_FDG', 1),
#  ('ADNI_FDG_Brain', 1),
#  ('3D_Emission_24mo_6i_16s', 1),
#  ('30_min_3D_FDG_6i_16s', 1),
#  ('20081024075053.', 1),
#  ('3D_Brain_ADNI', 1),
#  ('3D_BRAIN', 1),
#  ('022_S_0014.img__BRAIN-ADNI_', 1),
#  ('pet4adni', 1),
#  ('FDG_PET', 1),
#  ('3D_6x300s_4i_16s__FDG', 1),
#  ('3D_PET_BRAIN_ADNI-2_FDG', 1),
#  ('30_MIN_EMMI_-_Iter_Brain_Mod_FDG', 1),
#  ('FORE-ITERATIVEFDG6X5MIN3DBASELINE', 1),
#  ('FDG_PET_BRAIN_1', 1),
#  ('Brain_LM__DYNAMIC_rerecon__FDG', 1),
#  ('009_S_4388_FDG', 1),
#  ('RECON_ADNI3-BRAIN_FDG', 1),
#  ('PET_FDG_6x5_', 1),
#  ('ADNI3_3D_AC_FDG', 1),
#  ('PET_Brain_FDG__1___AC_', 1),
#  ('PET_AC_FDG', 1),
#  ('PET_COR_BRAIN_ADNI_#_3', 1),
#  ('30_Min_3D_FDG_6i_16s', 1),
#  ('ADNI', 1),
#  ('ADNI_PET_-FDG', 1),
#  ('PET2', 1),
#  ('adni_brain__6x5_', 1),
#  ('ADNI_BRAIN__6X5_', 1),
#  ('ADNIGo_FDG_6F_4i_16s', 1),
#  ('ADNI-GO_FDG_MODEL-24_FORE-ITER', 1),
#  ('ADNI3__FDG_Brain_30min_dyn', 1),
#  ('PET_AC_ADNI3_FDG', 1),
#  ('PET1a_FDG', 1),
#  ('Brain_ADNI-6month', 1),
#  ('PET_Brain_IT3_16BB_FDG', 1),
#  ('_3D_6x300s_-_Iter_Brain_Mode_FDG', 1),
#  ('FORE-ITERATIVE6X5MIN3DFDGBASELINE', 1),
#  ('ADNI_BRAIN_FDG_2ND_15min', 1),
#  ('_FDG', 1),
#  ('PET_ADNI_Iterative1_FDG', 1),
#  ('e+1_Dyn_Brain_VPHD_6i16s_AC', 1),
#  ('022_S_0219.img__BRAIN-PASS2_', 1),
#  ('ADNI-GO_FDG', 1),
#  ('EMISSION_6i_16s__FDG', 1),
#  ('ADNI_VUE_POINT_IT_FDG_3D', 1),
#  ('ADNI-2_RECON_1_FDG', 1),
#  ('ADNI_3_FDG_BRAIN_3Di__AC_', 1),
#  ('022_S_0096.img__BRAIN-PASS2_', 1)]

# %% [markdown]
# Looks like there are two main types: Some that have the word "dynamic" and some that have the word "averaged". What else do you notice about the differences among the different PET image types? (1 point)
# ________________________________________________________________________________________________________________________________________________________________
# Below, search for the patients with the greatest variety of images:

# %%
for patient in os.listdir(Path(DATA_PATH, 'FDGPET','ADNI',)): 
  if len(os.listdir(Path(DATA_PATH, 'FDGPET','ADNI',patient))) > 3: 
    print(patient, len(os.listdir(DATA_PATH/'FDGPET'/'ADNI'/patient)))
# Out:
# 024_S_0985 4
# 127_S_0259 6
# 021_S_0647 4
# 127_S_0754 4
# 003_S_1059 4
# 130_S_0232 4
# 126_S_0680 5
# 009_S_0751 5

# %% [markdown]
# Let's use the first patient and compare

# %%
patient_id_test = '127_S_0259'
os.listdir(DATA_PATH/'FDGPET'/'ADNI'/patient_id_test)
# Out:
# ['30-60_min_dynamic-3D_4i_16s_FDG',
#  '30-60_min_dynamic-3D_-_Iter__FDG',
#  '30_min_3D_FDG_4i_16s',
#  'ADNI_STATIC_BRAIN__6x5_',
#  '30-60_min_dynamic-3D_4i_16s__FDG',
#  '127_S_0259_fdg']

# %%
image_type_to_test = 'ADNI_STATIC_BRAIN__6x5_'

# %%
## Looking at the files, picking one of the descriptions above and looking at the file structure: 
glob.glob(str(Path(DATA_PATH,'FDGPET', 'ADNI',patient_id_test,image_type_to_test, '*', '*', '*', )))[0]
# Out:
# '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/127_S_0259/ADNI_STATIC_BRAIN__6x5_/2007-04-20_13_48_59.0/I49952/ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103402869_132_S30122_I49952.dcm'

# %%
len(glob.glob(str(Path(DATA_PATH,'FDGPET', 'ADNI',patient_id_test,image_type_to_test, '*', '*', '*', ))))
# Out:
# 210

# %% [markdown]
# Looks like the structure is as follows:
#
#
# `<root_path>/Module1_ADNI/FDGPET/ADNI/<patient_id>/<image_type>/<date>/<Series>/<full_image_name>.dcm`
#
# Let's see how many dates, series, and DICOM images there are in this particular image_type:

# %%
print('The number of dates in this image type is: '+ str(len(glob.glob(str(Path(DATA_PATH,'FDGPET', 'ADNI',patient_id_test,image_type_to_test, '*', ))))), 
      ' and they are: ', [x.split('/')[-1] for x in glob.glob(str(Path(DATA_PATH,'FDGPET', 'ADNI',patient_id_test,image_type_to_test, '*', )))])
# Out:
# The number of dates in this image type is: 1  and they are:  ['2007-04-20_13_48_59.0']

# %%
date_test = [x.split('/')[-1] for x in glob.glob(str(Path(DATA_PATH,'FDGPET','ADNI',patient_id_test,image_type_to_test, '*', )))][0]
image_series_test = [x.split('/')[-1] for x in glob.glob(str(Path(DATA_PATH,'FDGPET','ADNI',patient_id_test,image_type_to_test, date_test,'*' )))][0]

# %%
## In a single series, it looks like the DICOMs are numbered by their slice based on third to last element in the slice name.
os.listdir(Path(DATA_PATH,'FDGPET','ADNI',patient_id_test,image_type_to_test, date_test,image_series_test ))[:30]
# Out:
# ['ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103402869_132_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103356885_127_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103348479_120_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103201696_26_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103400447_130_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103330010_103_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103421354_151_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103458698_172_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103328853_102_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103540792_197_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103158165_23_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103455229_171_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103341916_114_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103306556_82_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103135430_2_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103549058_205_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103250197_68_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103336572_109_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103225696_47_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103347354_119_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103222212_44_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103500792_173_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103317963_92_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103154915_20_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103243712_62_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103405838_135_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103156008_21_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103257884_75_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103319009_93_S30122_I49952.dcm',
#  'ADNI_127_S_0259_PT_ADNI_STATIC_BRAIN__6x5___br_raw_20070423103147352_13_S30122_I49952.dcm']

# %%
len(os.listdir(Path(DATA_PATH,'FDGPET','ADNI',patient_id_test,image_type_to_test, date_test,image_series_test )))
# Out:
# 210

# %% [markdown]
# These files all have the extension ".dcm", which means that it's a DICOM file. These types of files have both pixel data and meta-data associated with the pixel data (image). Therefore, they require a special reader in python. A quick google search will tell you to use pydicom, but Colab doesn't have that pre-installed. We'll install it below:

# %%
# !pip install pydicom
# Out:
# Requirement already satisfied: pydicom in /usr/local/lib/python3.7/dist-packages (2.2.2)

# %%
import pydicom
import matplotlib.pyplot as plt

# %%
## Using the _30_ tag as a potential indicator that it's the slice at the center of the volume
first_dicom_dataset = pydicom.dcmread(glob.glob(str(Path(DATA_PATH,'FDGPET','ADNI',patient_id_test,image_type_to_test, date_test, image_series_test, '*_45_*')))[0])

# %%
## Looking at the components of a Dicom image/dataset: 
first_dicom_dataset
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 196
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Positron Emission Tomography Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.16.124.113543.6006.99.02616612684992636474
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.16.124.113543.6006.99.3181266211547127779
# (0002, 0016) Source Application Entity Title     AE: 'UWMOWS'
# -------------------------------------------------
# (0008, 0000) Group Length                        UL: 494
# (0008, 0005) Specific Character Set              CS: 'ISO_IR 100'
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY']
# (0008, 0012) Instance Creation Date              DA: '20070423'
# (0008, 0013) Instance Creation Time              TM: '093647.000'
# (0008, 0014) Instance Creator UID                UI: 2.16.124.113543.6006.99.09051108728847412991
# (0008, 0016) SOP Class UID                       UI: Positron Emission Tomography Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.16.124.113543.6006.99.02616612684992636474
# (0008, 0020) Study Date                          DA: '20070420'
# (0008, 0021) Series Date                         DA: '20070420'
# (0008, 0022) Acquisition Date                    DA: '20070420'
# (0008, 0023) Content Date                        DA: '20070420'
# (0008, 0030) Study Time                          TM: '133933.00'
# (0008, 0031) Series Time                         TM: '134859.00'
# (0008, 0032) Acquisition Time                    TM: '134859.00'
# (0008, 0033) Content Time                        TM: '164216.00'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'PT'
# (0008, 0070) Manufacturer                        LO: 'GEMS'
# (0008, 0080) Institution Name                    LO: 'UW-Madison, PET Imaging Center'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'ADNI STATIC BRAIN (6x5)'
# (0008, 1060) Name of Physician(s) Reading Study  PN: ''
# (0008, 1070) Operators' Name                     PN: ''
# (0008, 1090) Manufacturer's Model Name           LO: 'Advance'
# (0009, 0000) Private Creator                     UL: 2250
# (0009, 0010) Private tag data                    LO: 'GEMS_PETD_01'
# (0009, 1001) [GE Discovery PET Implementation Ve LO: 'GE Advance'
# (0009, 1003) [PET compatible_version]            SH: '02.00'
# (0009, 1004) [GE Advance Patient.software_versio SH: '06.00'
# (0009, 1006) [PET type]                          SL: 0
# (0009, 1007) [PET exam_id]                       UI: 2.16.124.113543.6006.99.3333241773747042182
# (0009, 1008) [PET compatible_version]            SH: '02.00'
# (0009, 1009) [PET software_version]              SH: '06.00'
# (0009, 100a) [PET scan_id]                       UI: 2.16.124.113543.6006.99.3336183348241909286
# (0009, 100b) [PET compatible_version]            SH: '02.00'
# (0009, 100c) [PET software_version]              SH: '06.00'
# (0009, 1011) [PET scanner_desc]                  LO: 'Advance'
# (0009, 1012) [PET manufacturer]                  LO: 'GEMS'
# (0009, 1014) [PET landmark_name]                 LO: 'Orbital Meatal Line'
# (0009, 1015) [PET landmark_abbrev]               SH: 'OM'
# (0009, 1016) [PET patient_position]              SL: 0
# (0009, 1017) [PET scan_perspective]              SL: 0
# (0009, 1018) [PET scan_type]                     SL: 0
# (0009, 1019) [PET scan_mode]                     SL: 1
# (0009, 101a) [PET start_condition]               SL: 1
# (0009, 101b) [PET start_cond_data]               SL: 0
# (0009, 101c) [PET sel_stop_cond]                 SL: 1
# (0009, 101d) [PET sel_stop_cond_data]            SL: 0
# (0009, 101e) [PET collect_deadtime]              SL: 1
# (0009, 101f) [PET collect_singles]               SL: 0
# (0009, 1020) [PET collect_countrate]             SL: 0
# (0009, 1021) [PET countrate_period]              SL: 1
# (0009, 1022) [PET delayed_events]                SL: 2
# (0009, 1023) [PET delayed_bias]                  SL: 100
# (0009, 1024) [PET word_size]                     SL: 2
# (0009, 1025) [PET axial_acceptance]              SL: 2
# (0009, 1026) [PET axial_angle_3d]                SL: 11
# (0009, 1027) [PET theta_compression]             SL: 0
# (0009, 1028) [PET axial_compression]             SL: 2
# (0009, 1029) [PET gantry_tilt_angle]             FL: 0.0
# (0009, 102a) [PET collimation]                   SL: 0
# (0009, 102b) [PET scan_fov]                      SL: 55
# (0009, 102c) [PET axial_fov]                     SL: 153
# (0009, 102d) [PET event_separation]              SL: 2
# (0009, 102e) [PET mask_width]                    SL: 0
# (0009, 1034) [PET triggers_acquired]             SL: 0
# (0009, 1035) [PET triggers_rejected]             SL: 0
# (0009, 1036) [PET tracer_name]                   LO: 'FDG -- fluorodeoxyglucose'
# (0009, 1038) [PET tracer_activity]               FL: 0.0
# (0009, 103a) [PET pre_inj_volume]                FL: 0.0
# (0009, 103c) [PET post_inj_activity]             FL: 0.0
# (0009, 103e) [PET radionuclide_name]             SH: '18F'
# (0009, 103f) [PET half_life]                     FL: 6588.0
# (0009, 1040) [PET positron_fraction]             FL: 0.9700000286102295
# (0009, 104d) [PET emission_present]              SL: 0
# (0009, 104e) [PET lower_axial_acc]               SL: -12
# (0009, 104f) [PET upper_axial_acc]               SL: 11
# (0009, 1050) [PET lower_coinc_limit]             SL: -6
# (0009, 1051) [PET upper_coinc_limit]             SL: 6
# (0009, 1052) [PET coinc_delay_offset]            SL: 56
# (0009, 1053) [PET coinc_output_mode]             SL: 800
# (0009, 1054) [PET upper_energy_limit]            SL: 650
# (0009, 1055) [PET lower_energy_limit]            SL: 300
# (0009, 1056) [PET normal_cal_id]                 UI: 2.16.124.113543.6006.99.363635984448070393
# (0009, 1057) [PET normal_2d_cal_id]              UI: 2.16.124.113543.6006.99.623294552483530938
# (0009, 1058) [PET blank_cal_id]                  UI: 2.16.124.113543.6006.99.1017279328905509068
# (0009, 1059) [PET wc_cal_id]                     UI: 2.16.124.113543.6006.99.6185075269308811632
# (0009, 105a) [PET derived]                       SL: 0
# (0009, 105c) [PET frame_id]                      UI: 2.16.124.113543.6006.99.1641511511371866224
# (0009, 105d) [PET scan_id]                       UI: 2.16.124.113543.6006.99.3336183348241909286
# (0009, 105e) [PET exam_id]                       UI: 2.16.124.113543.6006.99.3333241773747042182
# (0009, 1060) [PET compatible_version]            SH: '02.00'
# (0009, 1061) [PET software_version]              SH: '06.00'
# (0009, 1063) [PET frame_size]                    SL: 50415616
# (0009, 1064) [PET file_exists]                   SL: 0
# (0009, 1065) [PET patient_entry]                 SL: 0
# (0009, 1066) [PET table_height]                  FL: 179.5
# (0009, 1067) [PET table_z_position]              FL: -94.5
# (0009, 1069) [PET slice_count]                   SL: 265
# (0009, 106a) [PET start_location]                FL: -144.5
# (0009, 106b) [PET acq_delay]                     SL: 0
# (0009, 106d) [PET acq_duration]                  SL: 300
# (0009, 1070) [PET actual_stop_cond]              SL: 0
# (0009, 1071) [PET total_prompts]                 FD: 84498902.0
# (0009, 1072) [PET total_delays]                  FD: 17471071.0
# (0009, 1073) [PET frame_valid]                   SL: 1
# (0009, 1074) [PET validity_info]                 SL: 207
# (0009, 1075) [PET archived]                      SL: 0
# (0009, 1076) [PET compression]                   SL: 0
# (0009, 1077) [PET uncompressed_size]             SL: 50415616
# (0009, 1079) [PET compatible_version]            SH: '02.00'
# (0009, 107a) [PET software_version]              SH: '06.00'
# (0009, 107c) [PET is_source]                     SL: 0
# (0009, 107d) [PET is_contents]                   SL: 2
# (0009, 107e) [PET is_type]                       SL: 0
# (0009, 107f) [PET is_reference]                  DS: [0, 0, -0]
# (0009, 1080) [PET multi_patient]                 SL: 0
# (0009, 1084) [PET rotate]                        FL: 0.0
# (0009, 1085) [PET flip]                          SL: 0
# (0009, 1086) [PET zoom]                          FL: 1.0
# (0009, 1087) [PET pan_x]                         SL: 0
# (0009, 1088) [PET pan_y]                         SL: 0
# (0009, 108b) [PET recon_method]                  SL: 1
# (0009, 108c) [PET attenuation]                   SL: 7
# (0009, 108d) [PET atten_coefficient]             FL: 0.09600000083446503
# (0009, 108e) [PET bp_filter]                     SL: 1
# (0009, 1090) [PET bp_filter_order]               SL: 0
# (0009, 1091) [PET bp_center_l]                   FL: 0.0
# (0009, 1092) [PET bp_center_p]                   FL: 0.0
# (0009, 1093) [PET atten_smooth]                  SL: 5
# (0009, 1094) [PET atten_smooth_param]            SL: 9
# (0009, 1095) [PET angle_smooth_param]            SL: 3
# (0009, 1096) [PET wellcountercal_id]             UI: 2.16.124.113543.6006.99.6185075269308811632
# (0009, 1097) [PET trans_scan_id]                 UI: 2.16.124.113543.6006.99.5118270141985027707
# (0009, 1098) [PET norm_cal_id]                   UI: 2.16.124.113543.6006.99.363635984448070393
# (0009, 1099) [PET blnk_cal_id]                   UI: 2.16.124.113543.6006.99.1017279328905509068
# (0009, 109a) [PET cac_edge_threshold]            FL: 0.0
# (0009, 109b) [PET cac_skull_offset]              FL: 0.0
# (0009, 109d) [PET radial_filter_3d]              SL: 1
# (0009, 109e) [PET radial_cutoff_3d]              FL: 4.0
# (0009, 109f) [PET axial_filter_3d]               SL: 1
# (0009, 10a0) [PET axial_cutoff_3d]               FL: 8.5
# (0009, 10a1) [PET axial_start]                   FL: 0.0
# (0009, 10a2) [PET axial_spacing]                 FL: 4.25
# (0009, 10a3) [PET axial_angles_used]             SL: 11
# (0009, 10a4) [PET compatible_version]            SH: '02.00'
# (0009, 10a5) [PET software_version]              SH: '06.00'
# (0009, 10a6) [PET slice_number]                  SL: 26
# (0009, 10aa) [PET archived]                      SL: 0
# (0009, 10ab) [PET bp_center_x]                   FL: 0.0
# (0009, 10ac) [PET bp_center_y]                   FL: 0.0
# (0009, 10ad) [PET trans_frame_id]                UI: 2.16.124.113543.6006.99.01906853438965131223
# (0009, 10b9) [PET response_filt_parm]            FL: 4.0
# (0009, 10be) [PET ac_bp_filter]                  SL: 3
# (0009, 10bf) [PET ac_bp_filt_cut_off]            FL: 8.600000381469727
# (0009, 10c1) [PET ac_img_smooth]                 SL: 1
# (0009, 10c2) [PET ac_img_smooth_parm]            FL: 4.0
# (0009, 10c6) [PET seg_qc_parm]                   FL: 2.090675115585327
# (0009, 10c7) [PET overlap]                       SL: 0
# (0010, 0000) Group Length                        UL: 46
# (0010, 0010) Patient's Name                      PN: '127_S_0259'
# (0010, 0020) Patient ID                          LO: '127_S_0259'
# (0010, 0040) Patient's Sex                       CS: 'M'
# (0011, 0000) Private Creator                     UL: 20
# (0011, 0010) Private tag data                    LO: 'GEMS_PETD_01'
# (0013, 0000) Private Creator                     UL: 20
# (0013, 0010) Private tag data                    LO: 'GEMS_PETD_01'
# (0018, 0000) Group Length                        UL: 308
# (0018, 0050) Slice Thickness                     DS: '4.25'
# (0018, 0071) Acquisition Termination Condition   CS: 'TIME'
# (0018, 0073) Acquisition Start Condition         CS: 'MANU'
# (0018, 0074) Acquisition Start Condition Data    IS: '0'
# (0018, 0075) Acquisition Termination Condition D IS: '0'
# (0018, 1000) Device Serial Number                LO: '4_cgQWZauzpI'
# (0018, 1020) Software Versions                   LO: '06.00'
# (0018, 1063) Frame Time                          DS: None
# (0018, 1081) Low R-R Value                       IS: None
# (0018, 1082) High R-R Value                      IS: None
# (0018, 1083) Intervals Acquired                  IS: '0'
# (0018, 1084) Intervals Rejected                  IS: '0'
# (0018, 1100) Reconstruction Diameter             DS: '250.0'
# (0018, 1120) Gantry/Detector Tilt                DS: '0.0'
# (0018, 1147) Field of View Shape                 CS: 'CYLINDRICAL RING'
# (0018, 1149) Field of View Dimension(s)          IS: [550, 153]
# (0018, 1181) Collimator Type                     CS: 'NONE'
# (0018, 1210) Convolution Kernel                  SH: ['Rad:', ' rectangle', '  4.000000 mm', ' Ax:', ' rectangle', '  8.500000 mm']
# (0018, 1242) Actual Frame Duration               IS: '300000'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 0000) Group Length                        UL: 288
# (0020, 000d) Study Instance UID                  UI: 2.16.124.113543.6006.99.3333241773747042182
# (0020, 000e) Series Instance UID                 UI: 2.16.124.113543.6006.99.08268835961732142598
# (0020, 0010) Study ID                            SH: 'PT Study'
# (0020, 0011) Series Number                       IS: None
# (0020, 0013) Instance Number                     IS: '45'
# (0020, 0032) Image Position (Patient)            DS: [-125, -125, -106.25]
# (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, -0]
# (0020, 0052) Frame of Reference UID              UI: 2.16.124.113543.6006.99.3336183348241909286
# (0020, 1040) Position Reference Indicator        LO: 'Orbital Meatal Line'
# (0020, 1041) Slice Location                      DS: '-106.25'
# (0028, 0000) Group Length                        UL: 236
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 128
# (0028, 0011) Columns                             US: 128
# (0028, 0030) Pixel Spacing                       DS: [1.953125, 1.953125]
# (0028, 0051) Corrected Image                     CS: ['DECY', 'ATTN', 'SCAT', 'DTIM', 'RAN', 'RADL', 'DCAL', 'SLSENS', 'NORM', 'BLANK', 'NLOG']
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          SS: -4726
# (0028, 0107) Largest Image Pixel Value           SS: -29971
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '0.619518'
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0054, 0000) Group Length                        UL: 546
# (0054, 0013)  Energy Window Range Sequence  1 item(s) ----
#    (0054, 0014) Energy Window Lower Limit           DS: '300.0'
#    (0054, 0015) Energy Window Upper Limit           DS: '650.0'
#    ---------
# (0054, 0016)  Radiopharmaceutical Information Sequence  1 item(s) ----
#    (0018, 0031) Radiopharmaceutical                 LO: 'FDG -- fluorodeoxyglucose'
#    (0054, 0300)  Radionuclide Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'C-111A1'
#       (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#       (0008, 0104) Code Meaning                        LO: '18F'
#       ---------
#    (0054, 0304)  Radiopharmaceutical Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'Y-X1743'
#       (0008, 0102) Coding Scheme Designator            SH: '99SDM'
#       (0008, 0104) Code Meaning                        LO: 'FDG -- fluorodeoxyglucose'
#       ---------
#    ---------
# (0054, 0081) Number of Slices                    US: 35
# (0054, 0101) Number of Time Slices               US: 6
# (0054, 0202) Type of Detector Motion             CS: 'NONE'
# (0054, 1000) Series Type                         CS: ['DYNAMIC', 'IMAGE']
# (0054, 1001) Units                               CS: 'BQML'
# (0054, 1002) Counts Source                       CS: 'EMISSION'
# (0054, 1100) Randoms Correction Method           CS: 'RTSUB'
# (0054, 1102) Decay Correction                    CS: 'START'
# (0054, 1103) Reconstruction Method               LO: '3D Kinahan - Rogers'
# (0054, 1105) Scatter Correction Method           LO: 'Gaussian Fit'
# (0054, 1201) Axial Mash                          IS: [1, 2]
# (0054, 1202) Transverse Mash                     IS: '1'
# (0054, 1210) Coincidence Window Width            DS: '12.0'
# (0054, 1300) Frame Reference Time                DS: '300000.0'
# (0054, 1320) Slice Sensitivity Factor            DS: '1.0'
# (0054, 1321) Decay Factor                        DS: '1.04844'
# (0054, 1322) Dose Calibration Factor             DS: '28488.0'
# (0054, 1324) Dead Time Factor                    DS: '1.17659'
# (0054, 1330) Image Index                         US: 45
# (7fe0, 0010) Pixel Data                          OW: Array of 32768 elements

# %% [markdown]
# When you view the variable, you'll notice different numerical "tags". Each tag keeps a unique data field. Some important DICOM data fields for PET images include:
#
# *   Series Description
# *   Radiopharmaceutical
# *   Pixel Data
#
# You can usually find nearly any information you're looking for with respect to the image acqusition in these DICOM fields. Since some of these are manually input into the scanner, it is possible that the data field is subject to error. Let's access some of the tags and then look at the image:

# %%
## If we want to know the institution that this DICOM image was acquired at, 
## you can access a tag by its numerical value like this: 
first_dicom_dataset[0x8, 0x80]
## Note that we have to use 0x<number> format; otherwise Python won't know 
## the 0s preceding the code exist.
# Out:
# (0008, 0080) Institution Name                    LO: 'UW-Madison, PET Imaging Center'

# %%
## You can also use the name of the element: 
first_dicom_dataset['InstitutionName']
# Out:
# (0008, 0080) Institution Name                    LO: 'UW-Madison, PET Imaging Center'

# %%
## Or if you want the value only: 
first_dicom_dataset.InstitutionName
# Out:
# 'UW-Madison, PET Imaging Center'

# %% [markdown]
# Now let's look at the image itself, which is located at the "pixel_array" element of the DICOM dataset:

# %%
first_dicom_dataset.pixel_array.shape
# Out:
# (128, 128)

# %%
plt.imshow(first_dicom_dataset.pixel_array, cmap = 'gray')

# %% [markdown]
# Let's confirm that the `_45_` number in the file name corresponds to the slice number. To do that, let's load the dicom slice datasets into a dictionary with the key as this identifier, then sort the keys & plot the slices:

# %%
def read_all_dicom_slices(dicom_directory, 
                         ):
  """
  Will read in the images from a single dicom folder and return a dictionary of 
  those images with the key as the presumed slice number, and the value being the pixel array. 
  
  dicom_directory: Path or string that leads to the folder containing the slices 

  """
  dicom_image_dict = {}
  for image in glob.glob(str(Path(dicom_directory, '*'))): 
    key = image.split('/')[-1].split('_')[-3]
    dicom_image_dict[key]= pydicom.dcmread(image)
  return dicom_image_dict

# %%
first_dicom_dir =  Path(DATA_PATH,'FDGPET','ADNI',patient_id_test,image_type_to_test, date_test, image_series_test)
first_dicom_volume = read_all_dicom_slices(first_dicom_dir)

# %%
def visualize_dicom_volume(dicom_volume: dict): 
  """
  Takes a dicom volume, gives them the proper titles. 
  dicom_volume,  e.g. {'1': <pixel_data>, ...}
  output is to plot an appropriate size image of the voulme that one is interested in. 
  """
  num_rows = math.ceil(len(dicom_volume.keys())/5)
  keys_sorted = [str(x) for x in sorted([int(x) for x in list(dicom_volume.keys())])]
  plt.figure(figsize = (20, 15*num_rows))
  for i, key in enumerate(keys_sorted): # iterates through the dictionary, while the enumerate function keeps track of the index with i
      plt.subplot(5*num_rows,5,i+1)    # the number of images in the grid 
      value = dicom_volume[key]
      img = value.pixel_array
      plt.imshow(img, cmap= 'gray')
      plt.axis('off')
      plt.title(key)
  plt.show()

# %%
visualize_dicom_volume(first_dicom_volume)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# They do NOT look ordered nor as though the slice number corresponds pretty well with the way that it's named.

# %%
uniform_path_list = glob.glob(str(Path(DATA_PATH,'FDGPET','ADNI', '*', '*', '*', '*')))

# %%
uniform_path_list.sort()

# %%
uniform_path_list[:10]
# Out:
# ['/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_0295/ADNI_Brain_PET__Raw_FDG/2011-06-09_08_23_48.0/I239487',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_0413/ADNI_Brain_PET__Raw_FDG/2013-05-14_08_16_10.0/I384425',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_0685/ADNI_Brain_PET__Raw_FDG/2010-07-27_08_37_48.0/I187652',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_0685/ADNI_Brain_PET__Raw_FDG/2012-08-02_08_37_38.0/I321228',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_1261/ADNI_Brain_PET__Raw_FDG/2011-03-01_08_45_24.0/I221695',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_1261/ADNI_Brain_PET__Raw_FDG/2013-03-07_08_14_14.0/I363184',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_1280/ADNI_Brain_PET__Raw_FDG/2011-05-06_08_49_00.0/I233918',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_4213/ADNI_Brain_PET__Raw_FDG/2013-09-09_09_01_13.0/I388951',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_4225/ADNI_Brain_PET__Raw_FDG/2011-10-12_08_12_04.0/I260708',
#  '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_4262/ADNI_Brain_PET__Raw_FDG/2011-10-28_08_16_47.0/I263363']

# %% [markdown]
# Creating a CSV file from these middle slices:

# %%
filepath_df = pd.DataFrame({'FILEPATH_FDGPET_DICOM_FOLDER': [x for x in uniform_path_list]})

# %%
filepath_df.loc[0, 'FILEPATH_FDGPET_DICOM_FOLDER']
# Out:
# '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/ADNI/002_S_0295/ADNI_Brain_PET__Raw_FDG/2011-06-09_08_23_48.0/I239487'

# %%
filepath_df['AVG_OR_DYN'] = ['dyn' if 'dyn' in x.lower() else 'avg' for x in filepath_df.FILEPATH_FDGPET_DICOM_FOLDER]
filepath_df.AVG_OR_DYN.value_counts()
# Out:
# avg    890
# dyn     97
# Name: AVG_OR_DYN, dtype: int64

# %%
DATA_PATH
# Out:
# PosixPath('/content/drive/MyDrive/Data_Shortcut/Module1_ADNI')

# %%
filepath_df.to_csv(Path(DATA_PATH, 'CSVS', 'ADNI_FDGPET_FILEPATH_TO_DICOM_FOLDER.csv'))

# %% [markdown]
# Add in some of the clinical characteristics/outcomes that we had in the original patient dataframe to the filepath df:

# %%
data_df.head()
# Out:
#   Image Data ID     Subject Group Sex  ...      Type    Acq Date Format  Downloaded
# 0      I1479867  941_S_6962    AD   F  ...  Original   8/10/2021    DCM  12/02/2021
# 1      I1295819  941_S_6854    AD   M  ...  Original   2/24/2020    DCM  12/02/2021
# 2       I283469  941_S_4376    CN   F  ...  Original   2/08/2012    DCM  12/02/2021
# 3       I274743  941_S_4365    CN   M  ...  Original  12/30/2011    DCM  12/02/2021
# 4       I420334  941_S_4365    CN   M  ...  Original   4/16/2014    DCM  12/02/2021
#
# [5 rows x 12 columns]

# %%
filepath_df.head()
# Out:
#                         FILEPATH_FDGPET_DICOM_FOLDER AVG_OR_DYN
# 0  /content/drive/MyDrive/Data_Shortcut/Module1_A...        avg
# 1  /content/drive/MyDrive/Data_Shortcut/Module1_A...        avg
# 2  /content/drive/MyDrive/Data_Shortcut/Module1_A...        avg
# 3  /content/drive/MyDrive/Data_Shortcut/Module1_A...        avg
# 4  /content/drive/MyDrive/Data_Shortcut/Module1_A...        avg

# %%
filepath_df['PTID'] = [x.split('/')[8] for x in filepath_df.FILEPATH_FDGPET_DICOM_FOLDER]
filepath_df.PTID.value_counts()
# Out:
# 005_S_0610    7
# 131_S_0123    7
# 127_S_0259    7
# 027_S_0074    7
# 941_S_1202    6
#              ..
# 003_S_4119    1
# 128_S_5123    1
# 098_S_4201    1
# 009_S_5252    1
# 036_S_4820    1
# Name: PTID, Length: 509, dtype: int64

# %% [markdown]
# Going to check and see if there are duplicated patients in this PET data:

# %%
filepath_df.PTID.duplicated().value_counts()
# Out:
# False    509
# True     478
# Name: PTID, dtype: int64

# %%
filepath_df.shape
# Out:
# (987, 3)

# %%
data_df.Subject.duplicated().value_counts()
# Out:
# True     845
# False    656
# Name: Subject, dtype: int64

# %%
data_df = data_df.loc[~data_df.Subject.duplicated()]

# %%
consolidated_data_df = filepath_df.merge(data_df, left_on=['PTID'], right_on = 'Subject', how = 'left')

# %%
consolidated_data_df.shape
# Out:
# (987, 15)

# %%
consolidated_data_df.head()
# Out:
#                         FILEPATH_FDGPET_DICOM_FOLDER  ...  Downloaded
# 0  /content/drive/MyDrive/Data_Shortcut/Module1_A...  ...  12/02/2021
# 1  /content/drive/MyDrive/Data_Shortcut/Module1_A...  ...  12/02/2021
# 2  /content/drive/MyDrive/Data_Shortcut/Module1_A...  ...  12/02/2021
# 3  /content/drive/MyDrive/Data_Shortcut/Module1_A...  ...  12/02/2021
# 4  /content/drive/MyDrive/Data_Shortcut/Module1_A...  ...  12/02/2021
#
# [5 rows x 15 columns]

# %% [markdown]
# Our outcome will be the diagnosis which is indicated by the DX column. Let's see what the counts of diagnosis are:

# %%
consolidated_data_df.Group.value_counts()
# Out:
# CN    621
# AD    366
# Name: Group, dtype: int64

# %%
Path(DATA_PATH, 'CSVS', 'ADNI_FDGPET_FILEPATH_TO_DICOM_FOLDER_ClinicalData.csv')
# Out:
# PosixPath('/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/CSVS/ADNI_FDGPET_FILEPATH_TO_DICOM_FOLDER_ClinicalData.csv')

# %%
os.listdir('/content/drive/MyDrive/Data_Shortcut/')
# Out:
# ['Module2_BraTS', 'Module1_ADNI', 'csvs']

# %%
consolidated_data_df.to_csv(Path('/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/CSVS', 'ADNI_FDGPET_FILEPATH_TO_DICOM_FOLDER_ClinicalData.csv'))

# %%
consolidated_data_df.Group.value_counts()
# Out:
# CN    621
# AD    366
# Name: Group, dtype: int64

# %%
# [print(x) for x in consolidated_data_df['FILEPATH_MIDDLE_SLICES']];

# %% [markdown]
# To check, I'm going to look at the PET images from a few cognitively normal patients:

# %%
num_patients_visualize = 10
num_rows = math.ceil(num_patients_visualize/5)
plt.figure(figsize = (20, 15*num_rows))
CN_df = consolidated_data_df.loc[consolidated_data_df.Group == 'CN'].copy().reset_index(drop = True)
for i, row in CN_df[:num_patients_visualize].iterrows(): # iterates through the dictionary, while the enumerate function keeps track of the index with i
    plt.subplot(5*num_rows,5,i+1)    # the number of images in the grid 
    dicom_ds = pydicom.dcmread(row['FILEPATH_MIDDLE_SLICES'])
    img = dicom_ds.pixel_array
    plt.imshow(img, cmap= 'gray')
    plt.axis('off')
    plt.title(row['PTID']+' '+row['Group'])
plt.show()

# %%
num_patients_visualize = 10
num_rows = math.ceil(num_patients_visualize/5)
plt.figure(figsize = (20, 15*num_rows))
AD_df = consolidated_data_df.loc[consolidated_data_df.Group == 'AD'].copy().reset_index(drop = True)
for i, row in AD_df[:num_patients_visualize].iterrows(): # iterates through the dictionary, while the enumerate function keeps track of the index with i
    plt.subplot(5*num_rows,5,i+1)    # the number of images in the grid 
    dicom_ds = pydicom.dcmread(row['FILEPATH_MIDDLE_SLICES'])
    img = dicom_ds.pixel_array
    plt.imshow(img, cmap= 'gray')
    plt.axis('off')
    plt.title(row['PTID']+' '+row['Group'])
plt.show()

# %% [markdown]
# I see a general "hotter" trend in the AD patients. The next step will be to let the algorithm decide which "hot" features are useful for predicting AD from CN patients.

# %% [markdown]
# # Next steps
# Break into groups and
# 1.
