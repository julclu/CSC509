# %% [markdown]
# # Module 2, Notebook 1: Segmentation of gliomas in MRI scans
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/julclu/CSC509/blob/main/Module2/Module2_NB2_BraTS_TumorSegmentation.ipynb)
#
# ## Each pixel on image is labelled as :
#
# - Pixel is part of a tumor area (subregions: 1, 2, 4)
# - Pixel is not a part of tumor area (0)
#
# 0 - no tumor, 1 - necrotic/core/ non-enhancing, 2 - edema, 4 - enhancing
#
# ## In this jupyter notebook, we will be doing whole tumor (WT) segmentation. WT includes subregions 1, 2 and 4.
#
#
# ## Objectivies (What will we learn here?)
# 1. Setting up the env
# 2. Create training, validation and test ids
# 3. Image pre-processing
# 4. Image augmentation
# 5. Performance metrics for semantic segmentation
# 6. Loss functions for semantic segmentation
# 7. Building the Unet model
# 8. Training the model
# 9. Looking at the learning curve
# 10. Predicting using the Unet model
# 11. What next? It is time to play!

# %% [markdown]
# ## Step 1: Set up the env
#
# Download all the packages needed.

# %%
import os
import numpy as np
from numpy import expand_dims
import cv2
import nibabel as nib 
import matplotlib.pyplot as plt
import glob
import pandas as pd
from pathlib import Path
from google.colab import drive
import tensorflow as tf
print(tf.__version__)
from tensorflow import keras
from keras import layers
import keras.backend as K
from keras.models import Model
from keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization, Dropout
from tensorflow.keras.layers.experimental import preprocessing 
from tensorflow.keras.optimizers import *
from sklearn.model_selection import train_test_split
from IPython.display import clear_output

tf.config.run_functions_eagerly(True)
# Out:
# 2.6.0

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %% [markdown]
# Let's create a copy of the training folder for our use on colab vm.
#
# This part of the code should be executed only the first time. Once a copy is created you can comment out this cell.

# %%
# %cd /content/drive/MyDrive/
# %cp -av  /content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/ MICCAI_BraTS2020_TrainingData_Copy
# Out:
# /content/drive/MyDrive
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData' -> 'MICCAI_BraTS2020_TrainingData_Copy'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/MICCAI_BraTS2020_TrainingData' -> 'MICCAI_BraTS2020_TrainingData_Copy/MICCAI_BraTS2020_TrainingData'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/name_mapping.csv' -> 'MICCAI_BraTS2020_TrainingData_Copy/name_mapping.csv'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/survival_info.csv' -> 'MICCAI_BraTS2020_TrainingData_Copy/survival_info.csv'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_244'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244/BraTS20_Training_244_flair.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_244/BraTS20_Training_244_flair.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244/BraTS20_Training_244_t2.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_244/BraTS20_Training_244_t2.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244/BraTS20_Training_244_t1ce.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_244/BraTS20_Training_244_t1ce.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244/BraTS20_Training_244_seg.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_244/BraTS20_Training_244_seg.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_244/BraTS20_Training_244_t1.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_244/BraTS20_Training_244_t1.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_082'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082/BraTS20_Training_082_seg.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_082/BraTS20_Training_082_seg.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082/BraTS20_Training_082_t1.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_082/BraTS20_Training_082_t1.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082/BraTS20_Training_082_t1ce.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_082/BraTS20_Training_082_t1ce.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082/BraTS20_Training_082_t2.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_082/BraTS20_Training_082_t2.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_082/BraTS20_Training_082_flair.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_082/BraTS20_Training_082_flair.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_076'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_seg.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_076/BraTS20_Training_076_seg.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_t2.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_076/BraTS20_Training_076_t2.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_t1ce.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_076/BraTS20_Training_076_t1ce.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_flair.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_076/BraTS20_Training_076_flair.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_076/BraTS20_Training_076_t1.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_076/BraTS20_Training_076_t1.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_049' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_049'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training
nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_227/BraTS20_Training_227_t2.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_227/BraTS20_Training_227_flair.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_227/BraTS20_Training_227_flair.nii.gz'
# '/content/drive/MyDrive/Module2_BraTS/MICCAI_BraTS2020_TrainingData/BraTS20_Training_227/BraTS20_Training_227_t1.nii.gz' -> 'MICCAI_BraTS2020_TrainingData_Copy/BraTS20_Training_227/BraTS20_Training_227_t1.nii.gz'

# %% [markdown]
# ## Step 2: Now let's create the training, validation and test ids.

# %%
# Let's define the train data paths.
TRAIN_DATA_PATH = Path('/content/drive/MyDrive/MICCAI_BraTS2020_TrainingData_Copy')

# BraTS also has "ValidationData" which has only images and no segmentation masks. So we won't be using it in this notebook.

# %%
# Let's create the training, validation and test ids.

train_dir = [f.path for f in os.scandir(TRAIN_DATA_PATH) if f.is_dir()]

# We will create train, val and test ids from the train_dir dataset


def list_to_ids(dir:str):
    """
    Will convert the dir paths to ids by parsing the paths.
    dir: string, image dir paths in BRATS
    """
    x = []
    for i in range(0,len(dir)):
        x.append(dir[i].split('/')[-1])
    return x

ids = list_to_ids(train_dir) 

# Split dataset to create training ids, validation ids and test ids
# Here we have selected the size of test set as 20% which is a common practice.
train_ids, test_ids = train_test_split(ids,test_size=0.2) 

# Create validation ids by further splitting the train ids, we again use 20 % as size of valisation set. Validation set is also referred to as tuning set. 
train_ids, val_ids = train_test_split(train_ids,test_size=0.2)

# %%
# Now looks at the number of patient ids in training, validation and test sets
print(f'There are {len(train_ids)} patient ids in training set')
print(f'There are {len(val_ids)} patient ids in validation set')
print(f'There are {len(test_ids)} patient ids in test set')
# Out:
# There are 236 patient ids in training set
# There are 59 patient ids in validation set
# There are 74 patient ids in test set

# %% [markdown]
# ## Step 3: Let's do some image pre-processing. You have already learnt basics of reading and visualizing nifti images, selecting slices and looking at histograms.
#
# Here, we will look at some pre-processing steps specific to semantic segmentation. It's important to understand that the pro-processing steps could vary depending on the task at hand.

# %%
# Let's rewind and remember the type of images available: T1, T1CE, T2, FLAIR and corresponding masks

# We will use the read_patient_niftis module we had learnt in the previous notebook
def read_patient_niftis(patient_id: str, 
                        niftis_to_load = ['t1', 't1ce', 't2', 'flair', 'seg'], 
                        data_path = TRAIN_DATA_PATH):
  """
  Will read in the images from a single patient and return a dictionary of 
  those images with the key as the image type and the value as the nifti object. 
  patient_id: string of format '001' through '369', patient ID in BRATS
  niftis_to_load: default is list containing all the types of images that we care about; can sub in another list if desired. 
  data_path: default is DATA_PATH specified above with respect to the mounted google drive (in colab)

  """
  patient_image_dict = {}
  for image in niftis_to_load: 
    patient_image_dict[image]=nib.load(Path(data_path, f'{patient_id}', f'{patient_id}_{image}.nii.gz'))
  return patient_image_dict

# Let's take a look one of the image and the corresponding segmentation mask from the training set before we proceed
pt_img_dict = read_patient_niftis(train_ids[12])

# Now lets visualize all the images side by side to get a sense of what's happening.
plt.figure(figsize=(45,30)) # specifying the overall grid size
for i, (key, value) in enumerate(pt_img_dict.items()):
    plt.subplot(1, 5, i+1)
    plt.imshow(value._dataobj[:, :, value.shape[-1]//2].T, cmap='gray') # Looks halfway through the volume and transposes the image so that its facing upward. 
    plt.axis('off')
    plt.title(key, fontsize=30)
plt.show()

# %%
# For this semantic segmentation task, we will use T2 images.
# And we will focus on binary or whole tumor (WT) segmentation. In order to do so we will assign the same pixel intensity (1) to the 3 tumor sub regions (1, 2, 4)

t2_img = pt_img_dict['t2'].get_fdata()
seg_img = pt_img_dict['seg'].get_fdata()

def normalize(input_image = t2_img,
              input_mask = seg_img,
              percentile = 0.001,
              eps = 0.0000001):
    """
    Will read the input image and normalize the image between 0 and 1.
    Will read the input mask and assign pixel value 1 to all tumor subregions (1, 2, 4).
    input_image: default is t2_img, the image to be segmented.
    input_mask: default is seg_img, the ground truth or label.
    """
    img_array = np.ndarray.flatten(input_image)
    min_img, max_img = np.quantile(img_array, percentile), np.quantile(img_array, 1-percentile)
    img_normalized = ((input_image-min_img)/(max_img-min_img+eps)*255).astype(np.uint8)
    img_normalized = tf.cast(img_normalized, tf.float32) / 255
    
    mask_normalized = np.where(input_mask >=1, 1, 0)
    return img_normalized, mask_normalized

# Let's look at the images after normalizing
img, mask = normalize(t2_img, seg_img)
plt.figure(figsize=(20,30))
plt.subplot(1,3,1)
plt.imshow(tf.transpose(img[:,:,77]), cmap = 'gray')
plt.axis('off')
plt.title('t2', fontsize=20)
plt.subplot(1,3,2)
plt.imshow(tf.transpose(seg_img[:,:,77]), cmap = 'gray')
plt.axis('off')
plt.title('mask of sub regions', fontsize=20)
plt.subplot(1,3,3)
plt.imshow(tf.transpose(mask[:,:,77]), cmap = 'gray')
plt.axis('off')
plt.title('mask of whole tumor', fontsize=20)
# Out:
# Text(0.5, 1.0, 'mask of whole tumor')

# %% [markdown]
# ## Step 4: Let's look at image augmentation now.
#
# Augmentation is a technique to increase the diversity of your training set by applying random (but realistic) transformations, such as image rotation.
#
# Note: Augmentation should be applied only on the training set.

# %%
 # Let's look at examples of image augmentation now

# We will create a few pre-processing layers and apply it to the t2 image to understand how augmentation works

data_augmentation = tf.keras.Sequential([
  layers.RandomContrast(factor = 0.3),
  layers.RandomFlip("horizontal_and_vertical")
])

image = tf.transpose(img[:,:,77])
image = tf.expand_dims(image, 0)

plt.figure(figsize=(20, 10))
for i in range(6):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(2, 3, i + 1)
  plt.imshow(augmented_image[0], cmap='gray')
  plt.axis("off")

# %%
# Now that we understand how augmentation works, let's create a class for simple augmentation with random flipping.
class Augment(tf.keras.layers.Layer):
    def __init__(self, seed=42):
      super().__init__()
      # both use the same seed, so they'll make the same random changes.
      self.augment_inputs = preprocessing.RandomFlip(mode="horizontal_and_vertical", seed=seed)
      self.augment_labels = preprocessing.RandomFlip(mode="horizontal_and_vertical", seed=seed)

    def call(self, inputs, labels):
      inputs = self.augment_inputs(inputs)
      labels = self.augment_labels(labels)
      return inputs, labels

# %% [markdown]
# ## Step 5: Let's take a look at the performance metrics commonly used in semantic segmentation.
#
# The 2 common ones are
# - Dice
# - Jaccard/Intersection of Union (IoU)
#
# Both Dice and Jaccard indices are bounded between 0 and 1 with 0 indicating completely inaccurate model prediction and 1 indicating completely accurate model prediction.

# %%
# Dice
def dice_coef(y_true, y_pred):
    """
    Dice coefficient for semantic segmentation.
    
    Dice = (2*|X & Y|)/ (|X|+ |Y|)
         =  2*sum(|A*B|)/(sum(A^2)+sum(B^2))
    
    y_true: The ground truth tensor.
    y_pred: The predicted tensor
    smooth: Smoothing factor. Default is 100.    
    """
    
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# Jaccard/IoU
def jacard_coef(y_true, y_pred):
    """
    Jaccard coefficient for semantic segmentation. Also known as the IOU loss.
    
    Jaccard = (|X & Y|)/ (|X|+ |Y| - |X & Y|)
            = sum(|A*B|)/(sum(|A|)+sum(|B|)-sum(|A*B|))
    
    y_true: The ground truth tensor.
    y_pred: The predicted tensor
    smooth: Smoothing factor. Default is 100.    
    """
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + 1.0) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + 1.0)

# %% [markdown]
# ## Step 6: Let's take a look at loss functions for semantic segmentation.
#
# The default choice of loss function for segmentation and other classification tasks is Binary Cross-Entropy (BCE). Here since the metric  Dice or Jaccard Coefficient is being used to judge model performance, the loss functions that are derived from these metrics - typically in the form 1 - f(x) where f(x) is the metric in question.

# %%
# The 2 loss functions we will look at are Dice and Jaccard loss

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def jacard_coef_loss(y_true, y_pred):
    return -jacard_coef(y_true, y_pred)

# %% [markdown]
# ## Step 7: Now comes the most interesing bit of our learning!
#
# We will now build the Unet model we are going to use for semantic segmentation of WT.

# %%
# Define the UNet model
def get_unet(input_shape=(None, None, 1),
                  num_classes=1):
    inputs = Input(shape=input_shape)
    down1 = Conv2D(64, (3, 3), activation = 'relu', padding='same')(inputs)
    down1 = BatchNormalization()(down1)
    down1 = Conv2D(64, (3, 3), activation = 'relu', padding='same')(down1)
    down1 = BatchNormalization()(down1)
    down1_pool = MaxPooling2D((2, 2), strides=(2, 2))(down1)
    # 64

    down2 = Conv2D(128, (3, 3), activation = 'relu', padding='same')(down1_pool)
    down2 = BatchNormalization()(down2)
    down2 = Conv2D(128, (3, 3), activation = 'relu', padding='same')(down2)
    down2 = BatchNormalization()(down2)
    down2_pool = MaxPooling2D((2, 2), strides=(2, 2))(down2)
    # 32

    down3 = Conv2D(256, (3, 3), activation = 'relu', padding='same')(down2_pool)
    down3 = BatchNormalization()(down3)
    down3 = Conv2D(256, (3, 3), activation = 'relu', padding='same')(down3)
    down3 = BatchNormalization()(down3)
    down3_pool = MaxPooling2D((2, 2), strides=(2, 2))(down3)
    # 16

    down4 = Conv2D(512, (3, 3), activation = 'relu', padding='same')(down3_pool)
    down4 = BatchNormalization()(down4)
    down4 = Conv2D(512, (3, 3), activation = 'relu', padding='same')(down4)
    down4 = BatchNormalization()(down4)
    down4_pool = MaxPooling2D((2, 2), strides=(2, 2))(down4)
    # 8

    center = Conv2D(1024, (3, 3), activation = 'relu', padding='same')(down4_pool)
    center = BatchNormalization()(center)
    center = Conv2D(1024, (3, 3), activation = 'relu', padding='same')(center)
    center = BatchNormalization()(center)
    # center

    up4 = UpSampling2D((2, 2))(center)
    up4 = concatenate([down4, up4], axis=3)
    up4 = Conv2D(512, (3, 3), activation = 'relu', padding='same')(up4)
    up4 = BatchNormalization()(up4)
    up4 = Conv2D(512, (3, 3), activation = 'relu', padding='same')(up4)
    up4 = BatchNormalization()(up4)
    up4 = Conv2D(512, (3, 3), activation = 'relu', padding='same')(up4)
    up4 = BatchNormalization()(up4)
    # 16

    up3 = UpSampling2D((2, 2))(up4)
    up3 = concatenate([down3, up3], axis=3)
    up3 = Conv2D(256, (3, 3), activation = 'relu', padding='same')(up3)
    up3 = BatchNormalization()(up3)
    up3 = Conv2D(256, (3, 3), activation = 'relu', padding='same')(up3)
    up3 = BatchNormalization()(up3)
    up3 = Conv2D(256, (3, 3), activation = 'relu', padding='same')(up3)
    up3 = BatchNormalization()(up3)
    # 32

    up2 = UpSampling2D((2, 2))(up3)
    up2 = concatenate([down2, up2], axis=3)
    up2 = Conv2D(128, (3, 3), activation = 'relu', padding='same')(up2)
    up2 = BatchNormalization()(up2)
    up2 = Conv2D(128, (3, 3), activation = 'relu', padding='same')(up2)
    up2 = BatchNormalization()(up2)
    up2 = Conv2D(128, (3, 3), activation = 'relu', padding='same')(up2)
    up2 = BatchNormalization()(up2)
    # 64

    up1 = UpSampling2D((2, 2))(up2)
    up1 = concatenate([down1, up1], axis=3)
    up1 = Conv2D(64, (3, 3), activation = 'relu', padding='same')(up1)
    up1 = BatchNormalization()(up1)
    up1 = Conv2D(64, (3, 3), activation = 'relu', padding='same')(up1)
    up1 = BatchNormalization()(up1)
    up1 = Conv2D(64, (3, 3), activation = 'relu', padding='same')(up1)
    up1 = BatchNormalization()(up1)
    # 128

    classify = Conv2D(1, (1, 1), activation='sigmoid')(up1)

    model = Model(inputs=inputs, outputs=classify)
    model.compile(optimizer=Adam(learning_rate=0.0001), loss=dice_coef_loss, metrics=[dice_coef])
    return model

# %% [markdown]
# ## Lets visualize the model now!

# %%
model = get_unet()
tf.keras.utils.plot_model(model, show_shapes=True)

# %% [markdown]
# ## Step 8: Let's do some model training now.

# %%
# Let's create numpy arrays of training, validation and test images.

# For the sake of simplicity, we will use only the middle slice of each volume for this experiment.

X = []
Y = []

def create_numpy_array(patient_ids:str,
                       DATA_PATH):
    X = []
    Y = []
    
    for i in range(len(patient_ids)):
        pt_img_dict = read_patient_niftis(patient_ids[i],
                                          niftis_to_load = ['t2', 'seg'], 
                                          data_path = DATA_PATH)
        
        images = []
        for j, (key, value) in enumerate(pt_img_dict.items()):
            images.append(value._dataobj[:, :, value.shape[-1]//2].T)
          
        image, mask = normalize(images[0], images[1])
        X.append(expand_dims(image, axis=2))
        Y.append(expand_dims(mask, axis=2))   

    return np.asarray(X), np.asarray(Y)

X_train, Y_train = create_numpy_array(train_ids, TRAIN_DATA_PATH)
X_val, Y_val = create_numpy_array(val_ids, TRAIN_DATA_PATH)
X_test, Y_test = create_numpy_array(test_ids, TRAIN_DATA_PATH)

# %%
# Let's confirm the size of the training and validation arrays
print(f'There are {len(X_train)} images in training set')
print(f'There are {len(X_val)} images in validation set')
print(f'There are {len(X_test)} images in test set')


# Visualiza the images
plt.figure(figsize=(10,20))
plt.subplot(1,2,1)
plt.imshow(X_train[12][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('t2', fontsize=20)
plt.subplot(1,2,2)
plt.imshow(Y_train[12][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('mask', fontsize=20)
# Out:
# There are 236 images in training set
# There are 59 images in validation set
# There are 74 images in test set
# Text(0.5, 1.0, 'mask')

# %%
dataset_train = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
dataset_train = dataset_train.map(lambda x, y: {'image': x, 'segmentation_mask': y})
dataset_val = tf.data.Dataset.from_tensor_slices((X_val, Y_val))
dataset_val = dataset_val.map(lambda x, y: {'image': x, 'segmentation_mask': y})
dataset_test = tf.data.Dataset.from_tensor_slices((X_test, Y_test))
dataset_test = dataset_test.map(lambda x, y: {'image': x, 'segmentation_mask': y})
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
# Let's create image loader to resize the image
def load_image(datapoint):
    input_image = tf.image.resize(datapoint['image'], (128, 128))
    input_mask = tf.image.resize(datapoint['segmentation_mask'], (128, 128))

    return input_image, input_mask

# %%
TRAIN_LENGTH = len(train_ids)
BATCH_SIZE = 4
BUFFER_SIZE = 1000
STEPS_PER_EPOCH = TRAIN_LENGTH // BATCH_SIZE

# %%
train_images = dataset_train.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
val_images = dataset_val.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
test_images = dataset_test.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
# Build the input pipeline, applying the Augmentation after batching the inputs.
train_batches = (
    train_images
    .cache()
    .shuffle(BUFFER_SIZE)
    .batch(BATCH_SIZE)
    .repeat()
    .map(Augment())
    .prefetch(buffer_size=tf.data.AUTOTUNE))

val_batches = val_images.batch(BATCH_SIZE)
test_batches = test_images.batch(BATCH_SIZE)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
# Visualize an image example and its corresponding mask from the dataset.
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ['Input Image', 'True Mask', 'Predicted Mask']

    for i in range(len(display_list)):
      plt.subplot(1, len(display_list), i+1)
      plt.title(title[i])
      plt.imshow(tf.keras.preprocessing.image.array_to_img(display_list[i]), cmap = 'gray')
      plt.axis('off')
    plt.show()

# %%
for images, masks in train_batches.take(2):
    sample_image, sample_mask = images[0], masks[0]
    display([sample_image, sample_mask])

# %% [markdown]
# Do you notice the change in image resolution of the above images as compared to the original images? The previous images look sharper. This is because we resized the images to 128 x 128. You can play with the load_image module and change the image size to see if that affects the model performance!

# %%
# Let's write a function to show the predictions
def show_predictions(dataset=None, num=1):
    if dataset:
      for image, mask in dataset.take(num):
        pred_mask = model.predict(image)
        display([image[0], mask[0], pred_mask[0]])
    else:
      display([sample_image, sample_mask,
              model.predict(sample_image[tf.newaxis, ...])])

# %%
# Let's train the model now
smooth = 1.
EPOCHS = 100
VAL_SUBSPLITS = 5
VALIDATION_STEPS = len(val_ids)//BATCH_SIZE//VAL_SUBSPLITS

model_history = model.fit(train_batches, epochs=EPOCHS,
                          steps_per_epoch=STEPS_PER_EPOCH,
                          validation_steps=VALIDATION_STEPS,
                          validation_data=val_batches)
# Out:
# Epoch 1/100
# 59/59 [==============================] - 25s 342ms/step - loss: -0.1802 - dice_coef: 0.1802 - val_loss: -0.0825 - val_dice_coef: 0.0825
# Epoch 2/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.2547 - dice_coef: 0.2547 - val_loss: -0.1599 - val_dice_coef: 0.1599
# Epoch 3/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.2909 - dice_coef: 0.2909 - val_loss: -0.1831 - val_dice_coef: 0.1831
# Epoch 4/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.3245 - dice_coef: 0.3245 - val_loss: -0.5317 - val_dice_coef: 0.5317
# Epoch 5/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.3679 - dice_coef: 0.3679 - val_loss: -0.3946 - val_dice_coef: 0.3946
# Epoch 6/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.3908 - dice_coef: 0.3908 - val_loss: -0.4543 - val_dice_coef: 0.4543
# Epoch 7/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.4229 - dice_coef: 0.4229 - val_loss: -0.4713 - val_dice_coef: 0.4713
# Epoch 8/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.4588 - dice_coef: 0.4588 - val_loss: -0.5574 - val_dice_coef: 0.5574
# Epoch 9/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.4647 - dice_coef: 0.4647 - val_loss: -0.5037 - val_dice_coef: 0.5037
# Epoch 10/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.5137 - dice_coef: 0.5137 - val_loss: -0.3976 - val_dice_coef: 0.3976
# Epoch 11/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.5402 - dice_coef: 0.5402 - val_loss: -0.6365 - val_dice_coef: 0.6365
# Epoch 12/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.5585 - dice_coef: 0.5585 - val_loss: -0.6457 - val_dice_coef: 0.6457
# Epoch 13/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.5421 - dice_coef: 0.5421 - val_loss: -0.6408 - val_dice_coef: 0.6408
# Epoch 14/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.5703 - dice_coef: 0.5703 - val_loss: -0.7006 - val_dice_coef: 0.7006
# Epoch 15/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.5992 - dice_coef: 0.5992 - val_loss: -0.6797 - val_dice_coef: 0.6797
# Epoch 16/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.6103 - dice_coef: 0.6103 - val_loss: -0.6657 - val_dice_coef: 0.6657
# Epoch 17/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.6391 - dice_coef: 0.6391 - val_loss: -0.6770 - val_dice_coef: 0.6770
# Epoch 18/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.6578 - dice_coef: 0.6578 - val_loss: -0.7572 - val_dice_coef: 0.7572
# Epoch 19/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.6335 - dice_coef: 0.6335 - val_loss: -0.7289 - val_dice_coef: 0.7289
# Epoch 20/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.6601 - dice_coef: 0.6601 - val_loss: -0.7846 - val_dice_coef: 0.7846
# Epoch 21/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7074 - dice_coef: 0.7074 - val_loss: -0.7036 - val_dice_coef: 0.7036
# Epoch 22/100
# 59/59 [==============================] - 20s 341ms/step - loss: -0.7079 - dice_coef: 0.7079 - val_loss: -0.6972 - val_dice_coef: 0.6972
# Epoch 23/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7296 - dice_coef: 0.7296 - val_loss: -0.7066 - val_dice_coef: 0.7066
# Epoch 24/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.6843 - dice_coef: 0.6843 - val_loss: -0.7084 - val_dice_coef: 0.7084
# Epoch 25/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7306 - dice_coef: 0.7306 - val_loss: -0.7815 - val_dice_coef: 0.7815
# Epoch 26/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7347 - dice_coef: 0.7347 - val_loss: -0.7652 - val_dice_coef: 0.7652
# Epoch 27/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7594 - dice_coef: 0.7594 - val_loss: -0.8053 - val_dice_coef: 0.8053
# Epoch 28/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.7315 - dice_coef: 0.7315 - val_loss: -0.5432 - val_dice_coef: 0.5432
# Epoch 29/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7320 - dice_coef: 0.7320 - val_loss: -0.7155 - val_dice_coef: 0.7155
# Epoch 30/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7568 - dice_coef: 0.7568 - val_loss: -0.5503 - val_dice_coef: 0.5503
# Epoch 31/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.7344 - dice_coef: 0.7344 - val_loss: -0.1460 - val_dice_coef: 0.1460
# Epoch 32/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7397 - dice_coef: 0.7397 - val_loss: -0.7764 - val_dice_coef: 0.7764
# Epoch 33/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7411 - dice_coef: 0.7411 - val_loss: -0.6204 - val_dice_coef: 0.6204
# Epoch 34/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.7399 - dice_coef: 0.7399 - val_loss: -0.5319 - val_dice_coef: 0.5319
# Epoch 35/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7503 - dice_coef: 0.7503 - val_loss: -0.5641 - val_dice_coef: 0.5641
# Epoch 36/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7671 - dice_coef: 0.7671 - val_loss: -0.7751 - val_dice_coef: 0.7751
# Epoch 37/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7714 - dice_coef: 0.7714 - val_loss: -0.7821 - val_dice_coef: 0.7821
# Epoch 38/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7688 - dice_coef: 0.7688 - val_loss: -0.7527 - val_dice_coef: 0.7527
# Epoch 39/100
# 59/59 [==============================] - 20s 342ms/step - loss: -0.7793 - dice_coef: 0.7793 - val_loss: -0.7542 - val_dice_coef: 0.7542
# Epoch 40/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7875 - dice_coef: 0.7875 - val_loss: -0.7394 - val_dice_coef: 0.7394
# Epoch 41/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7919 - dice_coef: 0.7919 - val_loss: -0.7771 - val_dice_coef: 0.7771
# Epoch 42/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7829 - dice_coef: 0.7829 - val_loss: -0.7771 - val_dice_coef: 0.7771
# Epoch 43/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7701 - dice_coef: 0.7701 - val_loss: -0.7968 - val_dice_coef: 0.7968
# Epoch 44/100
# 59/59 [==============================] - 20s 344ms/step - loss: -0.7851 - dice_coef: 0.7851 - val_loss: -0.7527 - val_dice_coef: 0.7527
# Epoch 45/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.7689 - dice_coef: 0.7689 - val_loss: -0.7775 - val_dice_coef: 0.7775
# Epoch 46/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.7654 - dice_coef: 0.7654 - val_loss: -0.7844 - val_dice_coef: 0.7844
# Epoch 47/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.7861 - dice_coef: 0.7861 - val_loss: -0.8152 - val_dice_coef: 0.8152
# Epoch 48/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.7964 - dice_coef: 0.7964 - val_loss: -0.7645 - val_dice_coef: 0.7645
# Epoch 49/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8000 - dice_coef: 0.8000 - val_loss: -0.7747 - val_dice_coef: 0.7747
# Epoch 50/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.7761 - dice_coef: 0.7761 - val_loss: -0.7677 - val_dice_coef: 0.7677
# Epoch 51/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8179 - dice_coef: 0.8179 - val_loss: -0.8188 - val_dice_coef: 0.8188
# Epoch 52/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.8184 - dice_coef: 0.8184 - val_loss: -0.7465 - val_dice_coef: 0.7465
# Epoch 53/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.8094 - dice_coef: 0.8094 - val_loss: -0.7328 - val_dice_coef: 0.7328
# Epoch 54/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8004 - dice_coef: 0.8004 - val_loss: -0.7781 - val_dice_coef: 0.7781
# Epoch 55/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8085 - dice_coef: 0.8085 - val_loss: -0.7983 - val_dice_coef: 0.7983
# Epoch 56/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8072 - dice_coef: 0.8072 - val_loss: -0.8125 - val_dice_coef: 0.8125
# Epoch 57/100
# 59/59 [==============================] - 20s 348ms/step - loss: -0.8000 - dice_coef: 0.8000 - val_loss: -0.7856 - val_dice_coef: 0.7856
# Epoch 58/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.7854 - dice_coef: 0.7854 - val_loss: -0.8248 - val_dice_coef: 0.8248
# Epoch 59/100
# 59/59 [==============================] - 20s 348ms/step - loss: -0.8155 - dice_coef: 0.8155 - val_loss: -0.7657 - val_dice_coef: 0.7657
# Epoch 60/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.7902 - dice_coef: 0.7902 - val_loss: -0.6759 - val_dice_coef: 0.6759
# Epoch 61/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.7768 - dice_coef: 0.7768 - val_loss: -0.7397 - val_dice_coef: 0.7397
# Epoch 62/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8048 - dice_coef: 0.8048 - val_loss: -0.8142 - val_dice_coef: 0.8142
# Epoch 63/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8045 - dice_coef: 0.8045 - val_loss: -0.7687 - val_dice_coef: 0.7687
# Epoch 64/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.7979 - dice_coef: 0.7979 - val_loss: -0.7649 - val_dice_coef: 0.7649
# Epoch 65/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8143 - dice_coef: 0.8143 - val_loss: -0.8124 - val_dice_coef: 0.8124
# Epoch 66/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8079 - dice_coef: 0.8079 - val_loss: -0.7964 - val_dice_coef: 0.7964
# Epoch 67/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.8243 - dice_coef: 0.8243 - val_loss: -0.8120 - val_dice_coef: 0.8120
# Epoch 68/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8129 - dice_coef: 0.8129 - val_loss: -0.7835 - val_dice_coef: 0.7835
# Epoch 69/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.8024 - dice_coef: 0.8024 - val_loss: -0.8344 - val_dice_coef: 0.8344
# Epoch 70/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8162 - dice_coef: 0.8162 - val_loss: -0.7597 - val_dice_coef: 0.7597
# Epoch 71/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.7945 - dice_coef: 0.7945 - val_loss: -0.5551 - val_dice_coef: 0.5551
# Epoch 72/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.7940 - dice_coef: 0.7940 - val_loss: -0.7779 - val_dice_coef: 0.7779
# Epoch 73/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8079 - dice_coef: 0.8079 - val_loss: -0.7879 - val_dice_coef: 0.7879
# Epoch 74/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8006 - dice_coef: 0.8006 - val_loss: -0.7959 - val_dice_coef: 0.7959
# Epoch 75/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8164 - dice_coef: 0.8164 - val_loss: -0.7815 - val_dice_coef: 0.7815
# Epoch 76/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8087 - dice_coef: 0.8087 - val_loss: -0.8080 - val_dice_coef: 0.8080
# Epoch 77/100
# 59/59 [==============================] - 20s 345ms/step - loss: -0.8082 - dice_coef: 0.8082 - val_loss: -0.7780 - val_dice_coef: 0.7780
# Epoch 78/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8044 - dice_coef: 0.8044 - val_loss: -0.8103 - val_dice_coef: 0.8103
# Epoch 79/100
# 59/59 [==============================] - 20s 343ms/step - loss: -0.8289 - dice_coef: 0.8289 - val_loss: -0.7727 - val_dice_coef: 0.7727
# Epoch 80/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8104 - dice_coef: 0.8104 - val_loss: -0.7535 - val_dice_coef: 0.7535
# Epoch 81/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8276 - dice_coef: 0.8276 - val_loss: -0.8035 - val_dice_coef: 0.8035
# Epoch 82/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8164 - dice_coef: 0.8164 - val_loss: -0.7400 - val_dice_coef: 0.7400
# Epoch 83/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8183 - dice_coef: 0.8183 - val_loss: -0.8077 - val_dice_coef: 0.8077
# Epoch 84/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8072 - dice_coef: 0.8072 - val_loss: -0.8211 - val_dice_coef: 0.8211
# Epoch 85/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8263 - dice_coef: 0.8263 - val_loss: -0.8024 - val_dice_coef: 0.8024
# Epoch 86/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8305 - dice_coef: 0.8305 - val_loss: -0.7948 - val_dice_coef: 0.7948
# Epoch 87/100
# 59/59 [==============================] - 20s 346ms/step - loss: -0.8094 - dice_coef: 0.8094 - val_loss: -0.7989 - val_dice_coef: 0.7989
# Epoch 88/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8048 - dice_coef: 0.8048 - val_loss: -0.7728 - val_dice_coef: 0.7728
# Epoch 89/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8411 - dice_coef: 0.8411 - val_loss: -0.8180 - val_dice_coef: 0.8180
# Epoch 90/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8138 - dice_coef: 0.8138 - val_loss: -0.7396 - val_dice_coef: 0.7396
# Epoch 91/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8378 - dice_coef: 0.8378 - val_loss: -0.7926 - val_dice_coef: 0.7926
# Epoch 92/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8409 - dice_coef: 0.8409 - val_loss: -0.7984 - val_dice_coef: 0.7984
# Epoch 93/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8336 - dice_coef: 0.8336 - val_loss: -0.7975 - val_dice_coef: 0.7975
# Epoch 94/100
# 59/59 [==============================] - 20s 348ms/step - loss: -0.8274 - dice_coef: 0.8274 - val_loss: -0.7997 - val_dice_coef: 0.7997
# Epoch 95/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8427 - dice_coef: 0.8427 - val_loss: -0.8066 - val_dice_coef: 0.8066
# Epoch 96/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8373 - dice_coef: 0.8373 - val_loss: -0.8106 - val_dice_coef: 0.8106
# Epoch 97/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8328 - dice_coef: 0.8328 - val_loss: -0.8378 - val_dice_coef: 0.8378
# Epoch 98/100
# 59/59 [==============================] - 20s 347ms/step - loss: -0.8511 - dice_coef: 0.8511 - val_loss: -0.8284 - val_dice_coef: 0.8284
# Epoch 99/100
# 59/59 [==============================] - 21s 349ms/step - loss: -0.8446 - dice_coef: 0.8446 - val_loss: -0.8026 - val_dice_coef: 0.8026
# Epoch 100/100
# 59/59 [==============================] - 21s 348ms/step - loss: -0.8520 - dice_coef: 0.8520 - val_loss: -0.8117 - val_dice_coef: 0.8117

# %% [markdown]
# ## Step 9: Now let's take a look at the learning curve.
#
# Learning curves are a widely used diagnostic tool in machine learning for algorithms that learn from a training dataset incrementally. The model can be evaluated on the training dataset and on a hold out validation dataset after each update during training and plots of the measured performance can created to show learning curves.

# %%
# Let's take a look at the learning curve now
loss = model_history.history['loss']
val_loss = model_history.history['val_loss']

plt.figure()
plt.plot(model_history.epoch, loss, 'r', label='Training loss')
plt.plot(model_history.epoch, val_loss, 'bo', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([-1, 0])
plt.legend()
plt.show()

# %%
# Let's also look at how the dice coef changes
dice = model_history.history['dice_coef']
val_dice = model_history.history['val_dice_coef']

plt.figure()
plt.plot(model_history.epoch, dice, 'r', label='Training dice')
plt.plot(model_history.epoch, val_dice, 'bo', label='Validation dice')
plt.title('Training and Validation Dice')
plt.xlabel('Epoch')
plt.ylabel('Dice Value')
plt.ylim([0, 1])
plt.legend()
plt.show()

# %% [markdown]
# ## Step 10: Now we will look at the model predictions in the validation and test sets.

# %%
show_predictions(val_batches, 3)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %%
show_predictions(test_batches, 3)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py:4212: UserWarning: Even though the `tf.config.experimental_run_functions_eagerly` option is set, this option does not apply to tf.data functions. To force eager execution of tf.data functions, please use `tf.data.experimental.enable_debug_mode()`.
#   "Even though the `tf.config.experimental_run_functions_eagerly` "

# %% [markdown]
# ## Step 11: What next? There are so many things you could do here. So it is now time to play!
#
# As a home-work or self learning task, you can try a variety of experiments to understand how the model performance is affected.
#
# You can also do some of this as your term project.
#
# Try to think about what could improve the model performance?
# 1. Will increasing the size of training set help? We are just using 1 slice per volume, will using more slices help?
# 2. Will changing the hyper-parameters like optimizer, learning rate, loss function, epochs, batch size improve the model performance? For ex. you have already learnt about BCE loss function. What will happen if you change the loss function?
# 3. Will changing the type of image help? Is T2 the right image for the model? Should I try with T1/T1CE/FLAIR?
# 4. Can I use 2/3 channel input image instead of single channel? Can have 3 different images in the 3 channels, say T1, T2 and FLAIR? Will that give the model more information to perform better?
# 5. How is the learning curve for this trained model? Is it underfitting? Does it need more training? How much training is enough and when should I stop?
# 6. Can I modify the Unet model to improve the performance? What can I change?
#
# And there is so much more! This is just a starting point. Model training and hyper-parameter tuning is the fun part of any deep learning project.
#
# Next what?
# In this example we learnt a binary or 2 class segmentation problem. It can be extended to a multi-class problem.
#
# Another fun task to do would be to try a multi-class segmentation where you can try and predict the different sub-regions of the tumors. What will you need yo modify in the current code to change it to a multi-class problem?

# %%
# Let's look at an example of how we modify the create_numpy_array module if we want to have a multi channel image (for ex. T1, T2, FLAIR)


X = []
Y = []

def create_numpy_array(patient_ids:str,
                       DATA_PATH):
    X = []
    Y = []
    
    for i in range(len(patient_ids)):
        pt_img_dict = read_patient_niftis(patient_ids[i],
                                          niftis_to_load = ['t1', 't2', 'flair', 'seg'], 
                                          data_path = DATA_PATH)
        
        images = []
       
        for j, (key, value) in enumerate(pt_img_dict.items()):
            images.append(value._dataobj[:, :, value.shape[-1]//2].T)
        
        images_3 = cv2.merge((images[0],images[1],images[2]))
        image, mask = normalize(images_3, images[3])
        X.append(image)
        Y.append(expand_dims(mask, axis=2))   

    return np.asarray(X), np.asarray(Y)

X_train, Y_train = create_numpy_array(train_ids, TRAIN_DATA_PATH)
X_val, Y_val = create_numpy_array(val_ids, TRAIN_DATA_PATH)
X_test, Y_test = create_numpy_array(test_ids, TRAIN_DATA_PATH)

# %%
# Visualize the images
plt.figure(figsize=(20,40))
plt.subplot(1,5,1)
plt.imshow(X_val[11][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('t1', fontsize=20)
plt.subplot(1,5,2)
plt.imshow(X_val[11][:,:,1], cmap = 'gray')
plt.axis('off')
plt.title('t2', fontsize=20)
plt.subplot(1,5,3)
plt.imshow(X_val[11][:,:,2], cmap = 'gray')
plt.axis('off')
plt.title('flair', fontsize=20)
plt.subplot(1,5,4)
plt.imshow(X_val[11])
plt.axis('off')
plt.title('3 channels', fontsize=20)
plt.subplot(1,5,5)
plt.imshow(Y_val[11][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('mask', fontsize=20)

# %%
# Let's look at an example of how we change the numpy array if we want to have a multiple slices per volume


X = []
Y = []

def create_numpy_array(patient_ids:str,
                       DATA_PATH):
    X = []
    Y = []
    
    for i in range(len(patient_ids)):
        pt_img_dict = read_patient_niftis(patient_ids[i],
                                          niftis_to_load = ['t2', 'seg'], 
                                          data_path = DATA_PATH)
        
        images = []
        # Let's say you want 5 slices sampled every 10 slices centered around middle slice
        n = [-20, -10, 0, 10, 20]
        count = -1
        for k in n:
            for j, (key, value) in enumerate(pt_img_dict.items()):
                images.append(value._dataobj[:, :, ((value.shape[-1]//2) + k)].T)
            count = count + 1
               
            image, mask = normalize(images[count*2], images[(count*2)+1])
            X.append(expand_dims(image, axis=2))
            Y.append(expand_dims(mask, axis=2))   

    return np.asarray(X), np.asarray(Y)

X_train, Y_train = create_numpy_array(train_ids, TRAIN_DATA_PATH)
X_val, Y_val = create_numpy_array(val_ids, TRAIN_DATA_PATH)
X_test, Y_test = create_numpy_array(test_ids, TRAIN_DATA_PATH)

# %%
# Let's check the increase in the size of numpy array (we should see a 5 times increase)
print(f'There are {len(X_train)} images in training set')
print(f'There are {len(X_val)} images in validation set')
print(f'There are {len(X_test)} images in test set')

# %%
# Visualize the images
plt.figure(figsize=(20,40))
plt.subplot(1,4,1)
plt.imshow(X_val[11][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('t2', fontsize=20)
plt.subplot(1,4,2)
plt.imshow(Y_val[11][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('mask', fontsize=20)
plt.subplot(1,4,3)
plt.imshow(X_val[12][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('t2', fontsize=20)
plt.subplot(1,4,4)
plt.imshow(Y_val[12][:,:,0], cmap = 'gray')
plt.axis('off')
plt.title('mask', fontsize=20)
