# %%
import os
from google.colab import drive
from pathlib import Path

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
PATH = Path('/content/drive/MyDrive/Data_Shortcut/Notebooks')

# %%
os.chdir(PATH)

# %%
# !pwd
# Out:
# /content/drive/.shortcut-targets-by-id/1HO3yoD8HWsntn5dWbaSB55ZchXdofIbn/Notebooks

# %%
# !ls
# Out:
# Backup_Module1_NB0_Unzip_FDG.ipynb
# Backup_Module1_NB1_ADNI_FDGPET.ipynb
# GitInitiation.ipynb
# Intro_to_medical_imaging_formats.ipynb
# Module1_NB0_ADNI_UnzipAndRemoveDuplicates.ipynb
# Module1_NB1_ADNI_PET_DataWrangling.ipynb
# Module1_NB2_ADNI_MRI_DataWrangling.ipynb
# Module1_NB3_ADNI_ADClassification.ipynb
# Module2_NB1_BraTS_DataProcessing.ipynb
# Module2_NB2_BraTS_TumorSegmentation.ipynb

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/.shortcut-targets-by-id/1HO3yoD8HWsntn5dWbaSB55ZchXdofIbn/Notebooks/.git/

# %%
# !git add .

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes to be committed:
#   (use "git reset HEAD <file>..." to unstage)
#
# 	modified:   Backup_Module1_NB1_ADNI_FDGPET.ipynb
# 	modified:   GitInitiation.ipynb
# 	new file:   Intro_to_medical_imaging_formats.ipynb
# 	modified:   Module1_NB1_ADNI_PET_DataWrangling.ipynb
# 	modified:   Module1_NB2_ADNI_MRI_DataWrangling.ipynb
# 	modified:   Module1_NB3_ADNI_ADClassification.ipynb
# 	modified:   Module2_NB1_BraTS_DataProcessing.ipynb

# %%
# !git config --global user.email "julia.cluceru@gmail.com"

# %%
# !git config --global user.name "julclu"

# %%
# !git commit -m "Got updates to the Brats Processing data"
# Out:
# [main 4fa6fdc] Got updates to the Brats Processing data
#  7 files changed, 7 insertions(+), 6 deletions(-)
#  rewrite Backup_Module1_NB1_ADNI_FDGPET.ipynb (94%)
#  create mode 100644 Intro_to_medical_imaging_formats.ipynb
#  rewrite Module1_NB1_ADNI_PET_DataWrangling.ipynb (80%)
#  rewrite Module1_NB3_ADNI_ADClassification.ipynb (72%)
#  rewrite Module2_NB1_BraTS_DataProcessing.ipynb (76%)

# %%
# !git remote remove origin
# !git remote add origin https://julclu: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@github.com/julclu/CSC509.git

# %%
# !git branch -M main

# %%
# !git push -u origin main
# Out:
# Counting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 8.69 MiB | 8.31 MiB/s, done.
# Total 9 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/julclu/CSC509.git
#    1e11f5b..4fa6fdc  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
