# %%
import numpy as np
import os
from pathlib import Path
import glob
import pandas as pd
from collections import Counter
import math
from tqdm import tqdm
import subprocess as sub

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
DATA_PATH = Path('/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/')

# %%
os.listdir(Path(DATA_PATH, 'Zipped_data'))
# Out:
# ['ADNI_base1.zip',
#  'ADNI',
#  'ADNI_base2.zip',
#  'ADNI_base4.zip',
#  'ADNI_base3.zip',
#  'ADNI_base5.zip',
#  'AD_ADNI23_Base.zip',
#  'AD_AllTimepoints_FBB.zip',
#  'CN_AllTimepoints_FBB1.zip',
#  'CN_AllTimepoints_FBB.zip',
#  'CN_AllTimepoints_FBB2.zip',
#  'CN_AllTimepoints_FBB3.zip',
#  'CN_AllTimepoints_FBB4.zip',
#  'FDG_PET_CN_AD2.zip',
#  'FDG_PET_CN_AD4.zip',
#  'FDG_PET_CN_AD5.zip',
#  'FDG_PET_CN_AD3.zip',
#  'FDG_PET_CN_AD.zip',
#  'FDG_PET_CN_AD1.zip',
#  'FDG_PET_CN_AD6.zip',
#  'FDG_PET_CN_AD8.zip',
#  'FDG_PET_CN_AD7.zip',
#  'FDG_PET_CN_AD9.zip']

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD1.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD2.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD3.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD4.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD5.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD6.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD7.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD8.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %%
# !unzip /content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/FDG_PET_CN_AD9.zip -d '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/FDGPET/'

# %% [markdown]
# Just want to see how much additional information I can get from merging the PET data together:

# %%
os.listdir(DATA_PATH)
# Out:
# ['PET', 'Zipped_data', 'CSVS', 'ADNI_CIDS', 'MRI', 'FDGPET']

# %%
patient_list_PET_folder = os.listdir(DATA_PATH/'FDGPET'/'ADNI')

# %%
PET_list_Zip_folder = ['/'.join(x.split('/')[-2:]) for x in glob.glob(str(Path(DATA_PATH,'Zipped_data','ADNI', '*', '*')))]
PET_list_Zip_folder[:2]
# Out:
# ['023_S_1190/AV45_Coreg,_Avg,_Standardized_Image_and_Voxel_Size',
#  '023_S_1190/AV45_Co-registered,_Averaged']

# %%
PET_list_PET_folder = ['/'.join(x.split('/')[-2:]) for x in glob.glob(str(Path(DATA_PATH,'PET', '*', '*')))]
PET_list_PET_folder[:2]
# Out:
# ['023_S_4501/AV45_Co-registered_Dynamic',
#  '023_S_4501/AV45_Coreg,_Avg,_Standardized_Image_and_Voxel_Size']

# %%
## Yes = patients in both 
## No = patients in ZIP but not in PET folder 
acq_in_Zip = []
acq_not_in_PET = []

for acq in PET_list_Zip_folder: 
  if acq in PET_list_PET_folder:
    acq_in_Zip.append("yes")
  else: 
    acq_in_Zip.append('no')
    acq_not_in_PET.append(acq)
Counter(acq_in_Zip)
# Out:
# Counter({'no': 270, 'yes': 706})

# %%
len(acq_not_in_PET)
# Out:
# 270

# %%
acq = acq_not_in_PET[0]

# %%
ZIP_PATH = Path(DATA_PATH,'Zipped_data','ADNI')
PET_PATH = Path(DATA_PATH,'PET',)

# %%
os.listdir(Path(ZIP_PATH, acq))
# Out:
# ['2017-05-30_13_57_34.0', '2019-07-25_14_54_13.0']

# %%
str(Path(ZIP_PATH, acq))
# Out:
# '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/ADNI/022_S_6013/ADNI_Brain_PET__Raw_FBB'

# %%
str(PET_PATH)+'/'+acq.split('/')[0]+'/.'
# Out:
# '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/PET/022_S_6013/.'

# %%
str(PET_PATH)+'/'+acq.split('/')[0]
# Out:
# '/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/PET/022_S_6013'

# %%
for acq in acq_not_in_PET: 
  command = 'mv '+str(Path(ZIP_PATH, acq))+' '+str(PET_PATH)+'/'+acq.split('/')[0]+'/.'
  if acq.split('/')[0] in os.listdir(PET_PATH): 
    try: 
      # !{command}
    except: 
      print('failed for: ', acq)
  else: 
    os.makedirs(str(PET_PATH)+'/'+acq.split('/')[0], exist_ok = True)
    try: 
      # !{command}
    except: 
      print('failed for: ', acq)

# %%
PET_list_Zip_folder = ['/'.join(x.split('/')[-2:]) for x in glob.glob(str(Path(DATA_PATH,'Zipped_data','ADNI', '*', '*')))]
PET_list_PET_folder = ['/'.join(x.split('/')[-2:]) for x in glob.glob(str(Path(DATA_PATH,'PET', '*', '*')))]
acq_in_Zip = []
acq_not_in_PET = []
for acq in PET_list_Zip_folder: 
  if acq in PET_list_PET_folder:
    acq_in_Zip.append("yes")
  else: 
    acq_in_Zip.append('no')
    acq_not_in_PET.append(acq)
Counter(acq_in_Zip)
# Out:
# Counter({'yes': 706})

# %%
## Now going to remove the duplicated folders or merge them? 
duplicated_patient_ids = []
for patient_id in os.listdir(Path(DATA_PATH, 'PET')): 
  if '(' in patient_id: 
    if patient_id[:-4] in os.listdir(Path(DATA_PATH, 'PET')): 
      duplicated_patient_ids.append(patient_id)

# %%
for patient_id in duplicated_patient_ids: 
  first_set = set(os.listdir(Path(DATA_PATH,'PET', patient_id)))
  second_set = set(os.listdir(Path(DATA_PATH, 'PET',patient_id[:-4])))
  if first_set != second_set: 
    # print(patient_id)
    print('elts in first set, not in second: ', [x for x in first_set if x not in second_set])
    print('elts in second set, not in first: ', [x for x in second_set if x not in first_set])
    command = 'mv '+str(Path(DATA_PATH,'PET', patient_id[:-4], ))+'\\ \\'+patient_id[-3:-1]+'\\'+patient_id[-1:]+'/* '+str(Path(DATA_PATH, 'PET', patient_id[:-4]))+'/.'
    # print(command)
    try: 
      # !{command}
    except: 
      print('Failure for: ', command)

# %%
## Look to see the duplicated patient IDs have stuff in them 
duplicated_patient_ids = []
for patient_id in os.listdir(Path(DATA_PATH, 'PET')): 
  if '(' in patient_id:
    print(patient_id) 
    if len(os.listdir(Path(DATA_PATH, 'PET', patient_id))) > 0: 
      print(patient_id)
      print(os.listdir(Path(DATA_PATH, 'PET', patient_id)))
    else: 
      command = 'rm -r '+str(Path(DATA_PATH,'PET', patient_id[:-4], ))+'\\ \\'+patient_id[-3:-1]+'\\'+patient_id[-1:]
      print(command)
      try: 
        # !{command}
      except: 
        print('it didnt work')
# Out:
# 003_S_4354 (1)
# 003_S_4354 (1)
# ['AV45_Coreg,_Avg,_Std_Img_and_Vox_Siz,_Uniform_Resolution']

# %%
## Now going to remove the duplicated folders or merge them? 
duplicated_patient_ids = []
for patient_id in os.listdir(Path(DATA_PATH, 'PET')): 
  if '(' in patient_id: 
    if patient_id[:-4] in os.listdir(Path(DATA_PATH, 'PET')): 
      duplicated_patient_ids.append(patient_id)

# %%
Path(DATA_PATH, "PET")
# Out:
# PosixPath('/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/PET')

# %%
Counter([x.split('/')[-1] for x in glob.glob(str(Path(DATA_PATH, 'PET', '*', '*', )))]).most_common()
# Out:
# [('AV45_Coreg,_Avg,_Std_Img_and_Vox_Siz,_Uniform_Resolution', 645),
#  ('AV45_Co-registered,_Averaged', 639),
#  ('AV45_Coreg,_Avg,_Standardized_Image_and_Voxel_Size', 634),
#  ('AV45_Co-registered_Dynamic', 633),
#  ('AV45-Early_Coreg,_Dyn,_Std_Img_and_Vox_Siz,_Uniform_Resolution', 35),
#  ('AV45-Early_Coreg,_Avg,_Standardized_Image_and_Voxel_Size', 33),
#  ('AV45-Early_Coreg,_Avg,_Std_Img_and_Vox_Siz,_Uniform_Resolution', 32),
#  ('AV45-Early_Coreg,_Dyn,_Standardized_Image_and_Voxel_Size', 30),
#  ('ADNI_Brain_PET__Raw_FBB', 30),
#  ('ADNI3-BRAIN_FBB', 20),
#  ('PET_AC_FBB', 18),
#  ('ADNI_Brain_PET__Raw_AV45', 16),
#  ('ADNI_AV45_Brain_20min_dyn', 12),
#  ('Dyn_Brain_VPHD_6i16s_AC_FBB', 12),
#  ('90-110_min_dynamic-3D_4i_16s_FBB', 12),
#  ('Florbetaben_20_MIN_DYN_FBB', 11),
#  ('ADNI3__florbetaben_Brain_20min_dyn_FBB', 10),
#  ('PET_Brain_FBB', 9),
#  ('3D_FLORBETABEN_ADNI3___4i_16s_FBB', 9),
#  ('NEURACEQ_3D_Brain_AC_ADNI_FBB', 8),
#  ('AV45_Co-registered_Dynamic (1)', 7),
#  ('AV45_Co-registered,_Averaged (1)', 7),
#  ('Brain_ADNI3_Florbetaben_LM__AC__FBB', 7),
#  ('PET_Florbetaben_4x5__FBB', 7),
#  ('20_MIN_3D_AV45_4i_16s', 6),
#  ('ANONYMIZED_FBB', 6),
#  ('BRAIN_ADNI_FBB', 6),
#  ('ADNI3_AV45__AC__FBB', 6),
#  ('Florbetaben_Dyn_4x5min_2Di_336_2z_AllPass__AC__FBB', 6),
#  ('ADNI_3D_Brain_ITERATIVE__AV45', 5),
#  ('ADNI3_florbetaben_4X5_FBB', 5),
#  ('e+1_Dyn_Brain_VPHD_6i16s_AC_FBB', 5),
#  ('ADNI_GO_PRIMARY_FBB', 5),
#  ('DYNAMIC_Brain_AC_FBB', 5),
#  ('PET_Florbetaben_Brain_Iterative_FBB', 5),
#  ('AX_BRAIN_FBB_IR_CTAC_NF', 5),
#  ('50-70_min_dynamic-3D_4i_16s_AV45', 4),
#  ('20_min_AV-45_4i_16s__AV45', 4),
#  ('ADNI-2-AV-45_AV45', 4),
#  ('AV45_Coreg,_Avg,_Std_Img_and_Vox_Siz,_Uniform_Resolution (1)', 4),
#  ('AV45_Coreg,_Avg,_Standardized_Image_and_Voxel_Size (1)', 4),
#  ('50-70_min_dynamic-3D_-_Iter_AV45', 4),
#  ('ADNI_Brain_PET__Raw', 4),
#  ('ADNI_ITERATIVE_FBB', 4),
#  ('Florbetaben.4x5min.3D.440x.8i5sTOF.2z.AllPass_FBB', 4),
#  ('AX_BRAIN_FBB_IR_NF', 4),
#  ('AV45_4i_16s', 3),
#  ('ADNI_AV-45_4X5_AV45', 3),
#  ('PET_Brain__AV45', 3),
#  ('ADNI_BRAIN_3D__AV45', 3),
#  ('ADNI2_AV45__AC_', 3),
#  ('ADNI_ITERATIVE_AV45', 3),
#  ('PET_AC_3D_Brain_ADNI-GO_AV-45__AV45', 3),
#  ('Dyn_ADNI-GO_128x,4i20s,256mmFOV,NoFilter___AV45', 3),
#  ('BRAIN_EMISSION_-_Iter_Brain_AV45', 3),
#  ('BRAIN_EMISSION_4i_16s__AV45', 3),
#  ('PET_AC_NEURACEQ__Florbetaben__FBB', 3),
#  ('PET_Brain_-_DYNAMIC_4X5MIN', 3),
#  ('4x5minute_frames_4i_16s_FBB', 3),
#  ('PET_Florbetaben_Dynamic_FBB', 3),
#  ('ADNI-20-MIN__AC__FBB', 3),
#  ('3D_ADNI2_AV45_F18_ACQUI._4i_16s', 2),
#  ('ADNI_GO_PRIMARY__AV45', 2),
#  ('PET_Brain_AV_45__AV45', 2),
#  ('3D_BRAIN_AV-45_FORE__AV45', 2),
#  ('AV45_Dyn_4x5min_2Di_336_2z_AllPass__AC_', 2),
#  ('PET1_FBB', 2),
#  ('Florbetaben.4x5min.3D.440x.8i5sTOF.2z.AllPass', 2),
#  ('PET_Brain_AC_FBB', 2),
#  ('ADNI-20-MIN__AC_', 2),
#  ('Dyn_Florbetaben_128x,4i20s,256mmFOV,NoFilter__FBB', 2),
#  ('20_MIN_3D__-_Iter_Brain_Mode__4_FBB', 2),
#  ('PET_Brain_AV_45', 1),
#  ('ADNI-2_RECON_1_AV45', 1),
#  ('ADNI-2_RECON_1_Early_AV45', 1),
#  ('PET_Brain_DYN__Early_AV45', 1),
#  ('Early_20_minutes_-_Iter_Bra_AV45', 1),
#  ('3D_PET_BRAIN_ADNI-2_AV45', 1),
#  ('019-4477-AV45', 1),
#  ('EMISSION_4i_16s__AV45', 1),
#  ('ADNI-AV45__AC_', 1),
#  ('3D_BRAIN_ADNI-2_ITERATIVE-AV45', 1),
#  ('3D_ADNI-GO_AV45_F18_ACQ._4i_16s', 1),
#  ('AV-45_PET_BRAIN_2__AV45', 1),
#  ('ADNI-2_3D_Iterative_Brain__AV45', 1),
#  ('ADNI3_AV45__AC_', 1),
#  ('ADNI2_AV45__EARLY_ADD-ON___AC__Early_AV45', 1),
#  ('019-S-4252-03-AV45_', 1),
#  ('3D_PET_BRAIN_ADNI-2_AV45_20.4', 1),
#  ('FORE-ITER_CENTER_P__-5.00__AV45', 1),
#  ('PET1_AV45', 1),
#  ('ADNI_AV45_Brain_20min_early_dyn__Early_AV45', 1),
#  ('Florbetapir_Dynamic_4_Early_AV45', 1),
#  ('FORE-ITERATIVEAV-454X5MINBASELINE__AV45', 1),
#  ('FORE-ITERATIVEAV-454X5MIN3DBASELINE__AV45', 1),
#  ('PET_WB_AV45', 1),
#  ('PET_Brain_TOF_FBB', 1),
#  ('ADNI_GO_PRIMARY', 1),
#  ('PET_Brain_NEURACEQ_DYNAMIC_FBB', 1),
#  ('PET1B_FBB', 1),
#  ('PET_Brain_DYNAMIC_4X5MIN_FBB', 1),
#  ('PET_Florbetaben_Brain_Iterative__FBB', 1),
#  ('PET_AC_EARLY_FRAMES2_FBB', 1),
#  ('DYNAMIC_Brain_AC_REDO_FBB', 1),
#  ('20_MIN_3D_-_Iter_Brain_Mode__4_FBB', 1),
#  ('PET_AC', 1),
#  ('ADNI3_AV45__AC__CORRECT_FBB', 1),
#  ('PET_AC1_FRAMES_FBB', 1),
#  ('PET_AC_STATIC_EARLY_FRAMES_FBB', 1),
#  ('PET_AC_AMYLOID_FBB', 1),
#  ('ADNI_Brain_PET__Raw__FBB', 1),
#  ('TR_BRAIN_3D_FBB_IR_CTAC__NF', 1),
#  ('DYANMIC_Brain_AC_REDO_FBB', 1),
#  ('e+2_Dyn_Brain_VPHD_6i16s_AC_FBB', 1),
#  ('PET_AC__STATIC_EARLY_FRAMES_FBB', 1),
#  ('AV45_Dyn_4x5min_2Di_336_2z_AllPass__AC__FBB', 1),
#  ('TR_BRAIN_3D_FBB_IR_CTAC_NF', 1),
#  ('ADNI_F18-Florbetapir_Brain_FBB', 1),
#  ('Interation_8,_TOF_on_FBB', 1)]

# %%
glob.glob(str(Path(DATA_PATH, '*', '*', '037_S_4015', )))
# Out:
# ['/content/drive/MyDrive/Data_Shortcut/Module1_ADNI/Zipped_data/ADNI/037_S_4015']
